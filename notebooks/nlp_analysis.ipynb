# %%
import os
import sys

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
sys.path.append(os.path.join(os.path.join('..'), 'data/'))
    
    
    
from src.features.build import Provider, Dataset
import spacy
from spacy import displacy
import markovify
# _d = Dataset()

# %%
_d = Dataset()
# Out:
# Downloading file from s3
# Reading downloaded file
# Transforming dataset
# Transforming file......
# Editing text.......
# ['company-flow', 'chino-xl', 'dj-kayslay', 'black-sheep', 'ab-soul', 'aesop-rock', 'big-moe', 'common-sense', 'freddie-foxxx', 'brand-nubian', 'dayton-family', 'flesh-n-bone', '3rd-bass', 'defari', 'capone-n-noreaga', 'arsonists', 'canibus', 'big-l', 'bubba-sparxxx', 'd-12', 'daz-dillinger', 'az-the-visualiza', 'damian-marley', 'field-mob', 'big-punisher']

# %%
aesop = _d.df[_d.df['artist'] == 'aesop-rock']
aesop.head()
# Out:
#          index              song     ...       song_length unique_words
# 174914  174914  numb-to-the-guns     ...                39          748
# 174915  174915       getaway-car     ...                28          362
# 174916  174916      limelighters     ...                35          456
# 174917  174917           alchemy     ...                33          559
# 174918  174918  no-jumper-cables     ...                35          590
#
# [5 rows x 9 columns]

# %%
nlp = spacy.load('en_core_web_md')

# %%
aesop.loc[:,'lyrics_split'] = aesop['lyrics_transform'].apply(lambda x: x.split('\n'))

# aesop.loc[:,'nlp'] = aesop['lyrics_split'].apply(lambda x: [nlp(i) for i in x])

song = aesop[aesop['song'] == 'abandon-all-hope']

lyrics = song['lyrics_transform']
# Out:
# /Users/joel.stevens/.virtualenvs/aesopbot/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
lyrics = [i for i in song['lyrics'].tolist()[0].split('\n')]
lyrics_join = "\n".join(lyrics)

# %%
doc = nlp(lyrics_join)
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.is_alpha, token.is_stop)
# Out:
# Aesop aesop PROPN NNP compound Xxxxx True False
# Rock rock PROPN NNP ROOT Xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# Aesop aesop PROPN NNP compound Xxxxx True False
# Rock rock PROPN NNP appos Xxxx True False
# ) ) PUNCT -RRB- punct ) False False
# ... ... PUNCT NFP punct ... False False
# ( ( PUNCT -LRB- punct ( False False
# x16 x16 PROPN NNP ROOT xdd False False
# ) ) PUNCT -RRB- punct ) False False
#
#
#  SPACE
#  False False
# Is be VERB VBZ ROOT Xx True False
# a a DET DT det x True False
# love love NOUN NN nsubj xxxx True False
# such such ADJ JJ amod xxxx True False
# as as ADP IN prep xx True False
# that that DET DT pobj xxxx True False
# which which ADJ WDT dobj xxxx True False
# I -PRON- PRON PRP nsubj X True False
# exhibit exhibit VERB VBP relcl xxxx True False
# for for ADP IN prep xxx True False
# my -PRON- ADJ PRP$ poss xx True False
# practice practice NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# The the DET DT det Xxx True False
# factor factor NOUN NN nsubj xxxx True False
# which which ADJ WDT nsubj xxxx True False
# then then ADV RB advmod xxxx True False
# amalgamates amalgamate VERB VBZ relcl xxxx True False
# debates debate NOUN NNS dobj xxxx True False
# with with ADP IN prep xxxx True False
# straight straight ADJ JJ amod xxxx True False
# - - PUNCT HYPH punct - False False
# jackets jacket NOUN NNS pobj xxxx True False
# and and CCONJ CC cc xxx True False
# ROBES robes PROPN NNP conj XXXX True False
#
#
#  SPACE
#  False False
# Huddled huddle VERB VBD ROOT Xxxxx True False
# in in ADP IN prep xx True False
# brackets bracket NOUN NNS pobj xxxx True False
# that that ADJ WDT nsubj xxxx True False
# blacken blacken VERB VBP relcl xxxx True False
# the the DET DT det xxx True False
# average average ADJ JJ amod xxxx True False
# globe globe NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Xenophobe xenophobe PROPN NNP appos Xxxxx True False
# , , PUNCT , punct , False False
# loathe loathe VERB VB advcl xxxx True False
# to to PART TO aux xx True False
# modify modify VERB VB xcomp xxxx True False
# the the DET DT det xxx True False
# fly fly NOUN NN dobj xxx True False
# , , PUNCT , punct , False False
# feel feel VERB VB dep xxxx True False
# this this DET DT nsubj xxxx True False
# ... ... PUNCT : punct ... False False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# carve carve VERB VBP ROOT xxxx True False
# a a DET DT det x True False
# notch notch NOUN NN dobj xxxx True False
# in in ADP IN prep xx True False
# my -PRON- ADJ PRP$ poss xx True False
# wall wall NOUN NN pobj xxxx True False
# for for ADP IN prep xxx True False
# every every DET DT det xxxx True False
# stall stall NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# every every DET DT det xxxx True False
# fifth fifth ADJ JJ amod xxxx True False
# mark mark NOUN NN nsubj xxxx True False
# slants slant VERB VBZ conj xxxx True False
# diagonal diagonal ADJ JJ acomp xxxx True False
# to to PART TO aux xx True False
# symbolize symbolize VERB VB advcl xxxx True False
# your -PRON- ADJ PRP$ poss xxxx True False
# downfall downfall NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Drunky drunky PROPN NNP compound Xxxxx True False
# peasants peasant NOUN NNS appos xxxx True False
# , , PUNCT , punct , False False
# honor honor VERB VB conj xxxx True False
# the the DET DT det xxx True False
# shifty shifty ADJ JJ amod xxxx True False
# megatron megatron NOUN NN compound xxxx True False
# presence presence NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Slug slug PROPN NNP appos Xxxx True False
# a a DET DT det x True False
# bolt bolt NOUN NN dobj xxxx True False
# once once ADV RB mark xxxx True False
# ceremonies ceremony NOUN NNS nsubj xxxx True False
# of of ADP IN prep xx True False
# merit merit NOUN NN pobj xxxx True False
# turn turn VERB VB advcl xxxx True False
# blood blood NOUN NN compound xxxx True False
# sport sport NOUN NN dobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# Uh uh INTJ UH intj Xx True False
# ) ) PUNCT -RRB- punct ) False False
#
#
#  SPACE
#  False False
# Fought fight VERB VBD advcl Xxxxx True False
# in in ADP IN prep xx True False
# hella hella ADJ JJ amod xxxx True False
# high high ADJ JJ amod xxxx True False
# seas sea NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# I -PRON- PRON PRP nsubj X True False
# freeze freeze VERB VBP ROOT xxxx True False
# your -PRON- ADJ PRP$ poss xxxx True False
# mega mega ADJ JJ amod xxxx True False
# dumb dumb ADJ JJ amod xxxx True False
# company company NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Pumpin pumpin PROPN NNP amod Xxxxx True False
# ' ' PUNCT '' punct ' False False
# out out PART RP prt xxx True False
# wise wise ADJ JJ amod xxxx True False
# beads bead NOUN NNS appos xxxx True False
# like like ADP IN prep xxxx True False
# , , PUNCT , punct , False False
# fly fly VERB VB conj xxx True False
# sneak sneak VERB VB compound xxxx True False
# - - PUNCT HYPH punct - False False
# attacks attack NOUN NNS nmod xxxx True False
# on on ADP IN prep xx True False
# dry dry ADJ JJ amod xxx True False
# leaves leaf NOUN NNS pobj xxxx True False
# DUNCE dunce PROPN NNP dobj XXXX True False
#
#
#  SPACE
#  False False
# Crooked crooked ADJ JJ amod Xxxxx True False
# rumors rumor NOUN NNS nsubj xxxx True False
# turn turn VERB VBP ccomp xxxx True False
# zoomers zoomer NOUN NNS dobj xxxx True False
# when when ADV WRB advmod xxxx True False
# rookies rookie NOUN NNS compound xxxx True False
# talkin talkin INTJ UH poss xxxx True False
# ' ' PUNCT '' punct ' False False
#
#
#  SPACE
#  False False
# Bad bad ADJ JJ amod Xxx True False
# seeds seed NOUN NNS nsubj xxxx True False
# blossom blossom VERB VBP advcl xxxx True False
# the the DET DT det xxx True False
# wookie wookie NOUN NN nsubj xxxx True False
# walk walk NOUN NN ccomp xxxx True False
# , , PUNCT , punct , False False
# hawkin hawkin PROPN NNP nsubj xxxx True False
# ' ' PUNCT '' punct ' False False
#
#
#  SPACE
#  False False
# Let let VERB VBP conj Xxx True False
# a a DET DT det x True False
# sucker sucker NOUN NN compound xxxx True False
# drift drift NOUN NN ccomp xxxx True False
# , , PUNCT , punct , False False
# I -PRON- PRON PRP nsubj X True False
# lift lift VERB VBP ROOT xxxx True False
# up up PART RP prt xx True False
# every every DET DT det xxxx True False
# stone stone NOUN NN dobj xxxx True False
# prone prone ADJ JJ amod xxxx True False
# to to PART TO aux xx True False
# find find VERB VB xcomp xxxx True False
#
#
#  SPACE
#  False False
# the the DET DT det xxx True False
# point point NOUN NN dobj xxxx True False
# at at ADP IN prep xx True False
# which which ADJ WDT pobj xxxx True False
# repellent repellent NOUN NN compound xxxx True False
# signals signal NOUN NNS nsubj xxxx True False
# ultimately ultimately ADV RB advmod xxxx True False
# bind bind VERB VBP relcl xxxx True False
#
#
#  SPACE
#  False False
# When when ADV WRB advmod Xxxx True False
# a a DET DT det x True False
# pack pack NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True False
# style style NOUN NN pobj xxxx True False
# mimics mimic NOUN NNS pobj xxxx True False
# see see VERB VBP advcl xxx True False
# my -PRON- ADJ PRP$ poss xx True False
# brans bran NOUN NNS nsubj xxxx True False
# target target VERB VB ccomp xxxx True False
# the the DET DT det xxx True False
# cluster cluster NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# advance advance VERB VBP ROOT xxxx True False
# clutchin clutchin INTJ UH advmod xxxx True False
# ' ' PUNCT '' case ' False False
# the the DET DT det xxx True False
# mic mic NOUN NN appos xxx True False
# like like ADP IN prep xxxx True False
# bully bully NOUN NN pobj xxxx True False
# to to PART TO prep xx True False
# knuckle knuckle VERB VB compound xxxx True False
# duster duster NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# Innocent innocent PROPN NNP advcl Xxxxx True False
# , , PUNCT , punct , False False
# your -PRON- ADJ PRP$ poss xxxx True False
# riddles riddle NOUN NNS nsubj xxxx True False
# yield yield VERB VBP ROOT xxxx True False
# a a DET DT det x True False
# little little ADJ JJ amod xxxx True False
# plastic plastic NOUN NN compound xxxx True False
# blend blend NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Fuck fuck PROPN NNP appos Xxxx True False
# a a DET DT det x True False
# badge badge NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# light light VERB VB conj xxxx True False
# a a DET DT det x True False
# bonfire bonfire NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# dance dance VERB VB conj xxxx True False
# a a DET DT det x True False
# jig jig NOUN NN dobj xxx True False
# around around ADP IN prep xxxx True False
# a a DET DT det x True False
# pig pig NOUN NN pobj xxx True False
#
#
#  SPACE
#  False False
# Figurin figurin PROPN NNP ROOT Xxxxx True False
# ' ' PUNCT '' punct ' False False
# yeah yeah INTJ UH ROOT xxxx True False
# , , PUNCT , punct , False False
# I -PRON- PRON PRP nsubj X True False
# 'll will VERB MD aux 'xx False False
# land land VERB VB ROOT xxxx True False
# a a DET DT det x True False
# plan plan NOUN NN dobj xxxx True False
# on on ADP IN prep xx True False
# bleached bleached ADJ JJ amod xxxx True False
# fame fame NOUN NN compound xxxx True False
# trackers tracker NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# using use VERB VBG acl xxxx True False
# only only ADV RB advmod xxxx True False
# the the DET DT det xxx True False
# finest fine ADJ JJS amod xxxx True False
# i -PRON- PRON PRP nmod x True False
# m be VERB VBP nummod x True False
# post post NOUN NN npadvmod xxxx True False
# - - PUNCT HYPH punct - False False
# modern modern ADJ JJ amod xxxx True False
# terrain terrain NOUN NN compound xxxx True False
# mappers mapper NOUN NNS dobj xxxx True False
#
#
#  SPACE
#  False False
# Once once ADP IN advmod Xxxx True False
# my -PRON- ADJ PRP$ poss xx True False
# brethren brother NOUN NNS nsubj xxxx True False
# disperse disperse VERB VBP ROOT xxxx True False
# ... ... PUNCT NFP punct ... False False
#
#
#  SPACE
#  False False
# My -PRON- ADJ PRP$ poss Xx True False
# God god PROPN NNP npadvmod Xxx True False
# , , PUNCT , punct , False False
# you -PRON- PRON PRP nsubj xxx True False
# think think VERB VBP ROOT xxxx True False
# the the DET DT det xxx True False
# heaven heaven PROPN NNP nsubj xxxx True False
# 's 's PART POS case 'x False False
# touched touch VERB VBD ccomp xxxx True False
# the the DET DT det xxx True False
# earth earth NOUN NN dobj xxxx True False
# then then ADV RB advmod xxxx True False
#
#
#  SPACE
#  False False
# Thirstin thirstin PROPN NNP dep Xxxxx True False
# ' ' PART POS case ' False False
# a a DET DT det x True False
# perch perch NOUN NN dobj xxxx True False
# on on ADP IN prep xx True False
# a a DET DT det x True False
# bursted burst VERB VBN amod xxxx True False
# curse curse NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# But but CCONJ CC cc Xxx True False
# I -PRON- PRON PRP nsubj X True False
# do do VERB VBP aux xx True False
# n't not ADV RB neg x'x False False
# confide confide VERB VB ROOT xxxx True False
# wine wine NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True False
# water water NOUN NN conj xxxx True False
# chose choose VERB VBD conj xxxx True False
# me -PRON- PRON PRP dobj xx True False
#
#
#  SPACE
#  False False
# Bored bored ADJ JJ nsubj Xxxxx True False
# , , PUNCT , punct , False False
# lasso lasso VERB VB ccomp xxxx True False
# down down PART RP prt xxxx True False
# Polaris polaris PROPN NNPS dobj Xxxxx True False
# , , PUNCT , punct , False False
# let let VERB VB ROOT xxx True False
# the the DET DT det xxx True False
# glow glow NOUN NN nsubj xxxx True False
# amuse amuse VERB VB ccomp xxxx True False
# me -PRON- PRON PRP dobj xx True False
#
#
#  SPACE
#  False False
# OK ok INTJ UH intj XX True False
# I -PRON- PRON PRP nsubj X True False
# lay lie VERB VBD ROOT xxx True False
# me -PRON- PRON PRP dobj xx True False
# down down PART RP prt xxxx True False
# to to ADP IN aux xx True False
# sleep sleep NOUN NN advcl xxxx True False
# , , PUNCT , punct , False False
# creepin creepin NOUN NN conj xxxx True False
# ' ' PUNCT '' case ' False False
# a a DET DT det x True False
# slumber slumber NOUN NN dobj xxxx True False
# under under ADP IN prep xxxx True False
# red red ADJ JJ amod xxx True False
# skies sky NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# Heads head NOUN NNS compound Xxxxx True False
# splittin splittin VERB VBP ROOT xxxx True False
# ' ' PUNCT '' punct ' False False
# , , PUNCT , punct , False False
# straight straight ADV RB amod xxxx True False
# sippin sippin ADV RB appos xxxx True False
# ' ' PUNCT '' punct ' False False
# a a DET DT det x True False
# drip drip NOUN NN appos xxxx True False
# of of ADP IN prep xx True False
# dead dead ADJ JJ amod xxxx True False
# vibes vibe NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# It -PRON- PRON PRP nsubj Xx True False
# 's be VERB VBZ ROOT 'x False False
# red red ADJ JJ amod xxx True False
# tides tide NOUN NNS attr xxxx True False
# from from ADP IN prep xxxx True False
# here here ADV RB pcomp xxxx True False
# , , PUNCT , punct , False False
# stop stop VERB VB conj xxxx True False
# and and CCONJ CC cc xxx True False
# smell smell VERB VBP conj xxxx True False
# analog analog NOUN NN amod xxxx True False
# hell hell NOUN NN npadvmod xxxx True False
#
#
#  SPACE
#  False False
# Clenchin clenchin PROPN NNP poss Xxxxx True False
# ' ' PUNCT '' case ' False False
# a a DET DT det x True False
# stench stench NOUN NN ROOT xxxx True False
# of of ADP IN prep xx True False
# burnin burnin NOUN NN poss xxxx True False
# ' ' PUNCT '' case ' False False
# logics logic NOUN NNS pobj xxxx True False
# and and CCONJ CC cc xxx True False
# a a DET DT det x True False
# child child NOUN NN conj xxxx True False
# with with ADP IN prep xxxx True False
# yearning yearn VERB VBG pcomp xxxx True False
#
#
#  SPACE
#  False False
# optics optic NOUN NNS dobj xxxx True False
# ... ... PUNCT : punct ... False False
#
#
#  SPACE
#  False False
# Now now ADV RB advmod Xxx True False
# someone someone NOUN NN nsubjpass xxxx True False
# 's be VERB VBZ auxpass 'x False False
# approached approach VERB VBN ROOT xxxx True False
# the the DET DT det xxx True False
# ropes rope NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# shaking shake VERB VBG advcl xxxx True False
# like like ADP IN prep xxxx True False
# snow snow NOUN NN compound xxxx True False
# - - PUNCT HYPH punct - False False
# globes globe NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# Others others PROPN NNPS nsubj Xxxxx True False
# sought seek VERB VBD ccomp xxxx True False
# safety safety NOUN NN dobj xxxx True False
# in in ADP IN prep xx True False
# numbers number NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# other other ADJ JJ poss xxxx True False
# 's 's PART POS case 'x False False
# flows flow NOUN NNS nsubjpass xxxx True False
# got get VERB VBD auxpass xxx True False
# towed tow VERB VBN ROOT xxxx True False
# under under ADP IN prep xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# yeah yeah INTJ UH intj xxxx True False
# ) ) PUNCT -RRB- punct ) False False
#
#
#  SPACE
#  False False
# Still still ADV RB advmod Xxxxx True False
# another another DET DT nsubj xxxx True False
# took take VERB VBD ROOT xxxx True False
# a a DET DT det x True False
# turn turn NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True False
# crashed crash VERB VBD conj xxxx True False
# and and CCONJ CC cc xxx True False
# burned burn VERB VBD conj xxxx True False
# while while ADP IN mark xxxx True False
# others other NOUN NNS nsubj xxxx True False
# flee flee VERB VBP advcl xxxx True False
#
#
#  SPACE
#  False False
# But but CCONJ CC cc Xxx True False
# there there ADV EX expl xxxx True False
# will will VERB MD aux xxxx True False
# never never ADV RB neg xxxx True False
# be be VERB VB conj xx True False
# another another DET DT det xxxx True False
# starvin starvin NOUN NN poss xxxx True False
# ' ' PUNCT '' case ' False False
# marvel marvel NOUN NN attr xxxx True False
# like like ADP IN prep xxxx True False
# me -PRON- PRON PRP pobj xx True False
#
#
#  SPACE
#  False False
# See see VERB VB intj Xxx True False
# , , PUNCT , punct , False False
# there there ADV EX expl xxxx True False
# 's be VERB VBZ ROOT 'x False False
# a a DET DT det x True False
# time time NOUN NN attr xxxx True False
# when when ADV WRB advmod xxxx True False
# ... ... PUNCT : punct ... False False
# rhymin rhymin INTJ UH attr xxxx True False
# ' ' PUNCT '' punct ' False False
# ... ... PUNCT : punct ... False False
#
#
#  SPACE
#  False False
# Pain pain NOUN NN nsubj Xxxx True False
# combined combine VERB VBN acl xxxx True False
# ca can VERB MD aux xx True False
# n't not ADV RB neg x'x False False
# even even ADV RB advmod xxxx True False
# manage manage VERB VB ROOT xxxx True False
# to to PART TO aux xx True False
# tell tell VERB VB xcomp xxxx True False
# what what NOUN WP attr xxxx True False
# the the DET DT det xxx True False
# swell swell NOUN NN nsubj xxxx True False
# is be VERB VBZ ccomp xx True False
# , , PUNCT , punct , False False
# like like ADP IN prep xxxx True False
#
#
#  SPACE
#  False False
# Picture picture NOUN NN pobj Xxxxx True False
# your -PRON- ADJ PRP$ poss xxxx True False
# imagery imagery NOUN NN nsubj xxxx True False
# embellished embellish VERB VBN acl xxxx True False
# with with ADP IN prep xxxx True False
# the the DET DT det xxx True False
# hellish hellish ADJ JJ amod xxxx True False
# aspects aspect NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# swans swan NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# for for ADP IN prep xxx True False
# lone lone ADJ JJ amod xxxx True False
# facets facet NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# Soul soul PROPN NNP nsubj Xxxx True False
# crafted craft VERB VBD ROOT xxxx True False
# fat fat ADJ JJ amod xxx True False
# cats cat NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# burrowin burrowin NOUN NN dep xxxx True False
# ' ' PUNCT '' punct ' False False
# , , PUNCT , punct , False False
# left leave VERB VBD amod xxxx True False
# perrenial perrenial ADJ JJ amod xxxx True False
# tenants tenant NOUN NNS nsubj xxxx True False
# discouraged discourage VERB VBN conj xxxx True False
# in in ADP IN prep xx True False
#
#
#  SPACE
#  False False
# Discussin discussin PROPN NNP poss Xxxxx True False
# ' ' PART POS case ' False False
# my -PRON- ADJ PRP$ poss xx True False
# foresees foresee NOUN NNS pobj xxxx True False
# and and CCONJ CC cc xxx True False
# flourishing flourish VERB VBG conj xxxx True False
# , , PUNCT , punct , False False
# Uh uh INTJ UH intj Xx True False
# ! ! PUNCT . punct ! False False
#
#
#  SPACE
#  False False
# Searching search VERB VBG ROOT Xxxxx True False
# , , PUNCT , punct , False False
# perching perching ADJ JJ conj xxxx True False
# , , PUNCT , punct , False False
# poetic poetic ADJ JJ amod xxxx True False
# lead lead NOUN NN compound xxxx True False
# poison poison NOUN NN appos xxxx True False
#
#
#  SPACE
#  False False
# Poised poised PROPN NNP nsubj Xxxxx True False
# , , PUNCT , punct , False False
# imploised implois VERB VBD ROOT xxxx True False
# to to PART TO aux xx True False
# leak leak VERB VB xcomp xxxx True False
# a a DET DT det x True False
# little little ADJ JJ amod xxxx True False
# bit bit NOUN NN dobj xxx True False
# of of ADP IN prep xx True False
# boisture boisture NOUN NN pobj xxxx True False
# on on ADP IN prep xx True False
# your -PRON- ADJ PRP$ poss xxxx True False
# pride pride NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# 'm be VERB VBP ROOT 'x False False
# a a DET DT det x True False
# , , PUNCT , punct , False False
# animated animated ADJ JJ amod xxxx True False
# style style NOUN NN compound xxxx True False
# machine machine NOUN NN attr xxxx True False
# in in ADP IN prep xx True False
#
#
#  SPACE
#  False False
# a a DET DT det x True False
# veening veen VERB VBG amod xxxx True False
# faulty faulty ADJ JJ amod xxxx True False
# production production NOUN NN appos xxxx True False
# fueled fuel VERB VBN acl xxxx True False
# by by ADP IN agent xx True False
# nicotine nicotine NOUN NN compound xxxx True False
# suction suction NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# From from ADP IN prep Xxxx True False
# tux tux NOUN NN pobj xxx True False
# in in ADP IN prep xx True False
# my -PRON- ADJ PRP$ poss xx True False
# carnivore carnivore NOUN NN pobj xxxx True False
# to to ADP IN prep xx True False
# vipers viper NOUN NNS pobj xxxx True False
# in in ADP IN prep xx True False
# my -PRON- ADJ PRP$ poss xx True False
# garden garden NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# You -PRON- PRON PRP nsubj Xxx True False
# flash flash VERB VBP ROOT xxxx True False
# identify identify NOUN NN xcomp xxxx True False
# by by ADP IN agent xx True False
# the the DET DT det xxx True False
# genus genus NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# species specie NOUN NNS conj xxxx True False
# and and CCONJ CC cc xxx True False
# class class NOUN NN conj xxxx True False
#
#
#  SPACE
#  False False
# Start start VERB VBP dobj Xxxxx True False
# to to PART TO aux xx True False
# chuckle chuckle VERB VB advcl xxxx True False
#
#
#  SPACE
#  False False
# Buckle buckle PROPN NNP dobj Xxxxx True False
# the the DET DT det xxx True False
# architecture architecture NOUN NN dobj xxxx True False
# until until ADP IN mark xxxx True False
# it -PRON- PRON PRP nsubj xx True False
# fell fall VERB VBD advcl xxxx True False
# through through ADP IN prep xxxx True False
#
#
#  SPACE
#  False False
# Kill kill PROPN NNP pobj Xxxx True False
# the the DET DT det xxx True False
# survivors survivor NOUN NNS nsubj xxxx True False
# then then ADV RB advmod xxxx True False
# raise raise VERB VBP conj xxxx True False
# the the DET DT det xxx True False
# dead dead ADJ JJ dobj xxxx True False
# for for ADP IN prep xxx True False
# shock shock NOUN NN compound xxxx True False
# value value NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# By by ADP IN prep Xx True False
# the the DET DT det xxx True False
# time time NOUN NN pobj xxxx True False
# the the DET DT det xxx True False
# pending pend VERB VBG amod xxxx True False
# settlements settlement NOUN NNS nsubj xxxx True False
# fully fully ADV RB advmod xxxx True False
# negotiated negotiate VERB VBD relcl xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# yeah yeah INTJ UH ROOT xxxx True False
# I -PRON- PRON PRP nsubj X True False
# 'll will VERB MD ROOT 'xx False False
# ... ... PUNCT . punct ... False False
# ) ) PUNCT -RRB- punct ) False False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# 'll will VERB MD aux 'xx False False
# have have VERB VB aux xxxx True False
# put put VERB VBN ROOT xxx True False
# a a DET DT det x True False
# sonic sonic ADJ JJ amod xxxx True False
# youth youth NOUN NN dobj xxxx True False
# to to PART TO aux xx True False
# get get VERB VB advcl xxx True False
# myself -PRON- PRON PRP nsubj xxxx True False
# situated situate VERB VBN ccomp xxxx True False
#
#
#  SPACE
#  False False
# It -PRON- PRON PRP nsubj Xx True False
# 's be VERB VBZ ROOT 'x False False
# like like INTJ UH intj xxxx True False
# sadly sadly ADV RB advmod xxxx True False
# , , PUNCT , punct , False False
# my -PRON- ADJ PRP$ poss xx True False
# style style NOUN NN nsubj xxxx True False
# spooks spook NOUN NNS compound xxxx True False
# juveniles juvenile NOUN NNS attr xxxx True False
# like like ADP IN prep xxxx True False
# Boo boo PROPN NNP compound Xxx True False
# Radley radley PROPN NNP pobj Xxxxx True False
#
#
#  SPACE
#  False False
# Radically radically ADV RB advmod Xxxxx True False
# weak weak ADJ JJ amod xxxx True False
# assume assume VERB VBP ROOT xxxx True False
# the the DET DT det xxx True False
# Colonel colonel PROPN NNP compound Xxxxx True False
# Kurt kurt PROPN NNP dobj Xxxx True False
# 's 's PART POS case 'x False False
# in in ADP IN prep xx True False
# our -PRON- ADJ PRP$ poss xxx True False
# platoon platoon NOUN NN pobj xxxx True False
# soon soon ADV RB advmod xxxx True False
# enough enough ADV RB npadvmod xxxx True False
#
#
#  SPACE
#  False False
# That that DET DT nsubj Xxxx True False
# 's be VERB VBZ ccomp 'x False False
# one one NUM CD nummod xxx True False
# bluff bluff NOUN NN compound xxxx True False
# call call NOUN NN attr xxxx True False
# , , PUNCT , punct , False False
# toughens toughen VERB VBZ ROOT xxxx True False
# the the DET DT det xxx True False
# searcher searcher NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Stuttering stuttering PROPN NNP dobj Xxxxx True False
# , , PUNCT , punct , False False
# emerging emerge VERB VBG amod xxxx True False
# , , PUNCT , punct , False False
# gutter gutter NOUN NN compound xxxx True False
# urchin urchin NOUN NN conj xxxx True False
# , , PUNCT , punct , False False
# bursting burst VERB VBG advcl xxxx True False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# live live VERB VBP ROOT xxxx True False
# for for ADP IN prep xxx True False
# the the DET DT det xxx True False
# moment moment NOUN NN pobj xxxx True False
# of of ADP IN prep xx True False
# truth truth NOUN NN pobj xxxx True False
# when when ADV WRB advmod xxxx True False
# Big big ADJ JJ compound Xxx True False
# Willy willy PROPN NNP compound Xxxxx True False
# rapper rapper NOUN NN nsubj xxxx True False
#
#
#  SPACE
#  False False
# acknowledges acknowledge VERB VBZ advcl xxxx True False
# failure failure NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True False
# states state NOUN NNS conj xxxx True False
# " " PUNCT `` punct " False False
# Goddamn goddamn ADJ JJ nsubj Xxxxx True False
# my -PRON- ADJ PRP$ poss xx True False
# shit shit NOUN NN nsubj xxxx True False
# is be VERB VBZ aux xx True False
# trash trash NOUN NN ROOT xxxx True False
# " " PUNCT `` punct " False False
#
#
#  SPACE
#  False False
# " " PUNCT '' punct " False False
# It -PRON- PRON PRP nsubj Xx True False
# 's be VERB VBZ ROOT 'x False False
# time time NOUN NN attr xxxx True False
# to to PART TO aux xx True False
# let let VERB VB relcl xxx True False
# go go VERB VB xcomp xx True False
# " " PUNCT '' punct " False False
# , , PUNCT , punct , False False
# the the DET DT det xxx True False
# tin tin NOUN NN compound xxx True False
# man man NOUN NN nsubj xxx True False
# bangin bangin VERB VBG acomp xxxx True False
# ' ' PUNCT '' punct ' False False
# upon upon ADP IN prep xxxx True False
# his -PRON- ADJ PRP$ poss xxx True False
# chest chest NOUN NN pobj xxxx True False
# to to PART TO aux xx True False
# hear hear VERB VB advcl xxxx True False
# the the DET DT det xxx True False
# echo echo NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Heartless heartless ADJ JJ amod Xxxxx True False
# kid kid NOUN NN appos xxx True False
# , , PUNCT , punct , False False
# hollow hollow ADJ JJ amod xxxx True False
# compartments compartment NOUN NNS dobj xxxx True False
#
#
#  SPACE
#  False False
# See see VERB VBP ROOT Xxx True False
# we -PRON- PRON PRP dobj xx True False
# the the DET DT det xxx True False
# people people NOUN NNS appos xxxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# united united ADJ JJ pobj xxxx True False
# , , PUNCT , punct , False False
# starving starve VERB VBG csubj xxxx True False
# artistic artistic ADJ JJ amod xxxx True False
#
#
#  SPACE
#  False False
# Militia militia PROPN NNP dobj Xxxxx True False
# keep keep VERB VB conj xxxx True False
# movin movin NOUN NN oprd xxxx True False
# ' ' PUNCT '' punct ' False False
# in in ADP IN prep xx True False
# order order NOUN NN pobj xxxx True False
# to to PART TO aux xx True False
# form form VERB VB acl xxxx True False
# a a DET DT det x True False
# more more ADV RBR advmod xxxx True False
# perfect perfect ADJ JJ amod xxxx True False
# union union NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# 'm be VERB VBP aux 'x False False
# cluing cluing ADJ JJ ROOT xxxx True False
# into into ADP IN prep xxxx True False
# the the DET DT det xxx True False
# poison poison NOUN NN compound xxxx True False
# panoramics panoramic NOUN NNS pobj xxxx True False
# brewed brew VERB VBN acl xxxx True False
# in in ADP IN prep xx True False
# panic panic NOUN NN compound xxxx True False
# situations situation NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# It -PRON- PRON PRP nsubj Xx True False
# fucks fuck VERB VBZ ROOT xxxx True False
# a a DET DT det x True False
# little little ADJ JJ npadvmod xxxx True False
# with with ADP IN prep xxxx True False
# my -PRON- ADJ PRP$ poss xx True False
# brittle brittle ADJ JJ amod xxxx True False
# gift gift NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# tell tell VERB VBP ROOT xxxx True False
# myself -PRON- PRON PRP dobj xxxx True False
# " " PUNCT `` punct " False False
# Stay stay VERB VB xcomp Xxxx True False
# " " PUNCT '' punct " False False
# ( ( PUNCT -LRB- punct ( False False
# Stay stay VERB VB dep Xxxx True False
# ) ) PUNCT -RRB- punct ) False False
# ... ... PUNCT NFP punct ... False False
# up up PART RP advmod xx True False
# high high ADJ JJ ROOT xxxx True False
#
#
#  SPACE
#  False False
# make make VERB VBP conj xxxx True False
# a a DET DT det x True False
# mockery mockery NOUN NN dobj xxxx True False
# of of ADP IN prep xx True False
# Sun sun PROPN NNP pobj Xxx True False
# and and CCONJ CC cc xxx True False
# moon moon NOUN NN conj xxxx True False
# and and CCONJ CC cc xxx True False
# star star NOUN NN conj xxxx True False
# til til ADP IN mark xxx True False
# they -PRON- PRON PRP nsubj xxxx True False
# hand hand VERB VBP advcl xxxx True False
# over over PART RP prt xxxx True False
# the the DET DT det xxx True False
# sky sky NOUN NN dobj xxx True False
#
#
#  SPACE
#  False False
# My -PRON- ADJ PRP$ poss Xx True False
# de de PROPN NNP nmod xx True False
# luxe luxe NOUN NN nsubj xxxx True False
# is be VERB VBZ ROOT xx True False
# , , PUNCT , punct , False False
# fluxes flux NOUN NNS attr xxxx True False
# , , PUNCT , punct , False False
# pivots pivot NOUN NNS attr xxxx True False
# to to ADP IN prep xx True False
# where where ADV WRB advmod xxxx True False
# the the DET DT det xxx True False
# crux crux NOUN NN nsubj xxxx True False
# is be VERB VBZ pcomp xx True False
#
#
#  SPACE
#  False False
# Invade invade PROPN NNP xcomp Xxxxx True False
# the the DET DT det xxx True False
# town town NOUN NN dobj xxxx True False
# while while ADP IN mark xxxx True False
# village village NOUN NN compound xxxx True False
# elders elder NOUN NNS nsubj xxxx True False
# holler holler VERB VBP advcl xxxx True False
# " " PUNCT `` punct " False False
# Who who NOUN WP dobj Xxx True False
# the the DET DT det xxx True False
# fuck fuck NOUN NN poss xxxx True False
# 's be VERB VBZ case 'x False False
# this this DET DT dobj xxxx True False
# ? ? PUNCT . punct ? False False
# " " PUNCT `` punct " False False
#
#
#  SPACE
#  False False
# See see PROPN NNP advcl Xxx True False
# hipper hip ADJ JJR amod xxxx True False
# cats cat NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# aggravated aggravated ADJ JJ amod xxxx True False
# trudge trudge NOUN NN appos xxxx True False
# through through ADP IN prep xxxx True False
# the the DET DT det xxx True False
# muds mud NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# Quickin quickin PROPN NNP poss Xxxxx True False
# ' ' PART POS case ' False False
# ones one NOUN NNS appos xxxx True False
# , , PUNCT , punct , False False
# plots plot NOUN NNS nsubj xxxx True False
# thicken thicken VERB VBP ROOT xxxx True False
# like like INTJ UH prep xxxx True False
# , , PUNCT , punct , False False
# coagulated coagulate VERB VBD amod xxxx True False
# blood blood NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Rugged rugged PROPN NNP amod Xxxxx True False
# serpentines serpentin VERB VBZ compound xxxx True False
# climb climb NOUN NN relcl xxxx True False
# , , PUNCT , punct , False False
# pebble pebble NOUN NN amod xxxx True False
# to to ADP IN prep xx True False
# rock rock NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# Let let VERB VB ROOT Xxx True False
# your -PRON- ADJ PRP$ poss xxxx True False
# pretty pretty ADV RB advmod xxxx True False
# pink pink ADJ JJ amod xxxx True False
# cloud cloud NOUN NN nsubj xxxx True False
# nine nine NUM CD nummod xxxx True False
# expectations expectation NOUN NNS nsubj xxxx True False
# please please VERB VBP ccomp xxxx True False
# you -PRON- PRON PRP dobj xxx True False
# not not ADV RB neg xxx True False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# 'm be VERB VBP ROOT 'x False False
# , , PUNCT , punct , False False
# Ae ae PROPN NNP nmod Xx True False
# - - PUNCT HYPH punct - False False
# fuckin'-sop fuckin'-sop PROPN NNP attr xxxx'-xxx False False
# Rock rock PROPN NNP nmod Xxxx True False
# , , PUNCT , punct , False False
# mic mic PROPN NNP amod xxx True False
# bizarro bizarro NOUN NN conj xxxx True False
#
#
#  SPACE
#  False False
# Proper proper PROPN NNP amod Xxxxx True False
# application application NOUN NN ROOT xxxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# soul soul NOUN NN pobj xxxx True False
# by by ADP IN prep xx True False
# my -PRON- ADJ PRP$ poss xx True False
# standard standard NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# Candid candid VERB VBD amod Xxxxx True False
# once once ADV RB advmod xxxx True False
# position position NOUN NN npadvmod xxxx True False
# from from ADP IN prep xxxx True False
# which which ADJ WDT pobj xxxx True False
# instigations instigation NOUN NNS nsubj xxxx True False
# spawn spawn VERB VBP relcl xxxx True False
#
#
#  SPACE
#  False False
# And and CCONJ CC cc Xxx True False
# man man NOUN NN conj xxx True False
# , , PUNCT , punct , False False
# I -PRON- PRON PRP nsubj X True False
# plan plan VERB VBP ROOT xxxx True False
# to to PART TO aux xx True False
# die die VERB VB xcomp xxx True False
# with with ADP IN prep xxxx True False
# a a DET DT det x True False
# mic mic NOUN NN pobj xxx True False
# in in ADP IN prep xx True False
# my -PRON- ADJ PRP$ poss xx True False
# hand hand NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# it -PRON- PRON PRP nsubj xx True False
# 's be VERB VBZ ROOT 'x False False
# like like ADP IN intj xxxx True False
# ... ... PUNCT NFP punct ... False False
#
#
#  SPACE
#  False False
# Abandon abandon VERB VBP advcl Xxxxx True False
# all all DET DT det xxx True False
# hope hope VERB VBP dobj xxxx True False
# yo yo INTJ UH dobj xx True False
# , , PUNCT , punct , False False
# abandon abandon VERB VB ROOT xxxx True False
# all all DET DT det xxx True False
# hope hope NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# it -PRON- PRON PRP nsubj xx True False
# 's be VERB VBZ ROOT 'x False False
# like like ADP IN intj xxxx True False
#
#
#  SPACE
#  False False
# Abandon abandon VERB VBP advcl Xxxxx True False
# all all DET DT det xxx True False
# hope hope VERB VBP dobj xxxx True False
# yo yo INTJ UH dobj xx True False
# , , PUNCT , punct , False False
# abandon abandon VERB VB ROOT xxxx True False
# all all DET DT det xxx True False
# hope hope NOUN NN dobj xxxx True False
# ... ... PUNCT . punct ... False False

# %%
for token in doc:
    print(token.lemma_)
# Out:
# aesop
# rock
# (
# aesop
# rock
# )
# ...
# (
# x16
# )
#
#
# be
# a
# love
# such
# as
# that
# which
# -PRON-
# exhibit
# for
# -PRON-
# practice
#
#
# the
# factor
# which
# then
# amalgamate
# debate
# with
# straight
# -
# jacket
# and
# robes
#
#
# huddle
# in
# bracket
# that
# blacken
# the
# average
# globe
#
#
# xenophobe
# ,
# loathe
# to
# modify
# the
# fly
# ,
# feel
# this
# ...
#
#
# -PRON-
# carve
# a
# notch
# in
# -PRON-
# wall
# for
# every
# stall
#
#
# every
# fifth
# mark
# slant
# diagonal
# to
# symbolize
# -PRON-
# downfall
#
#
# drunky
# peasant
# ,
# honor
# the
# shifty
# megatron
# presence
#
#
# slug
# a
# bolt
# once
# ceremony
# of
# merit
# turn
# blood
# sport
# (
# uh
# )
#
#
# fight
# in
# hella
# high
# sea
# ,
# -PRON-
# freeze
# -PRON-
# mega
# dumb
# company
#
#
# pumpin
# '
# out
# wise
# bead
# like
# ,
# fly
# sneak
# -
# attack
# on
# dry
# leaf
# dunce
#
#
# crooked
# rumor
# turn
# zoomer
# when
# rookie
# talkin
# '
#
#
# bad
# seed
# blossom
# the
# wookie
# walk
# ,
# hawkin
# '
#
#
# let
# a
# sucker
# drift
# ,
# -PRON-
# lift
# up
# every
# stone
# prone
# to
# find
#
#
# the
# point
# at
# which
# repellent
# signal
# ultimately
# bind
#
#
# when
# a
# pack
# of
# style
# mimic
# see
# -PRON-
# bran
# target
# the
# cluster
#
#
# -PRON-
# advance
# clutchin
# '
# the
# mic
# like
# bully
# to
# knuckle
# duster
#
#
# innocent
# ,
# -PRON-
# riddle
# yield
# a
# little
# plastic
# blend
#
#
# fuck
# a
# badge
# ,
# light
# a
# bonfire
# ,
# dance
# a
# jig
# around
# a
# pig
#
#
# figurin
# '
# yeah
# ,
# -PRON-
# will
# land
# a
# plan
# on
# bleached
# fame
# tracker
#
#
# use
# only
# the
# fine
# -PRON-
# be
# post
# -
# modern
# terrain
# mapper
#
#
# once
# -PRON-
# brother
# disperse
# ...
#
#
# -PRON-
# god
# ,
# -PRON-
# think
# the
# heaven
# 's
# touch
# the
# earth
# then
#
#
# thirstin
# '
# a
# perch
# on
# a
# burst
# curse
#
#
# but
# -PRON-
# do
# not
# confide
# wine
# and
# water
# choose
# -PRON-
#
#
# bored
# ,
# lasso
# down
# polaris
# ,
# let
# the
# glow
# amuse
# -PRON-
#
#
# ok
# -PRON-
# lie
# -PRON-
# down
# to
# sleep
# ,
# creepin
# '
# a
# slumber
# under
# red
# sky
#
#
# head
# splittin
# '
# ,
# straight
# sippin
# '
# a
# drip
# of
# dead
# vibe
#
#
# -PRON-
# be
# red
# tide
# from
# here
# ,
# stop
# and
# smell
# analog
# hell
#
#
# clenchin
# '
# a
# stench
# of
# burnin
# '
# logic
# and
# a
# child
# with
# yearn
#
#
# optic
# ...
#
#
# now
# someone
# be
# approach
# the
# rope
# ,
# shake
# like
# snow
# -
# globe
#
#
# others
# seek
# safety
# in
# number
# ,
# other
# 's
# flow
# get
# tow
# under
# (
# yeah
# )
#
#
# still
# another
# take
# a
# turn
# and
# crash
# and
# burn
# while
# other
# flee
#
#
# but
# there
# will
# never
# be
# another
# starvin
# '
# marvel
# like
# -PRON-
#
#
# see
# ,
# there
# be
# a
# time
# when
# ...
# rhymin
# '
# ...
#
#
# pain
# combine
# can
# not
# even
# manage
# to
# tell
# what
# the
# swell
# be
# ,
# like
#
#
# picture
# -PRON-
# imagery
# embellish
# with
# the
# hellish
# aspect
# of
# the
# swan
#
#
# for
# lone
# facet
#
#
# soul
# craft
# fat
# cat
# ,
# burrowin
# '
# ,
# leave
# perrenial
# tenant
# discourage
# in
#
#
# discussin
# '
# -PRON-
# foresee
# and
# flourish
# ,
# uh
# !
#
#
# search
# ,
# perching
# ,
# poetic
# lead
# poison
#
#
# poised
# ,
# implois
# to
# leak
# a
# little
# bit
# of
# boisture
# on
# -PRON-
# pride
#
#
# -PRON-
# be
# a
# ,
# animated
# style
# machine
# in
#
#
# a
# veen
# faulty
# production
# fuel
# by
# nicotine
# suction
#
#
# from
# tux
# in
# -PRON-
# carnivore
# to
# viper
# in
# -PRON-
# garden
#
#
# -PRON-
# flash
# identify
# by
# the
# genus
# ,
# specie
# and
# class
#
#
# start
# to
# chuckle
#
#
# buckle
# the
# architecture
# until
# -PRON-
# fall
# through
#
#
# kill
# the
# survivor
# then
# raise
# the
# dead
# for
# shock
# value
#
#
# by
# the
# time
# the
# pend
# settlement
# fully
# negotiate
# (
# yeah
# -PRON-
# will
# ...
# )
#
#
# -PRON-
# will
# have
# put
# a
# sonic
# youth
# to
# get
# -PRON-
# situate
#
#
# -PRON-
# be
# like
# sadly
# ,
# -PRON-
# style
# spook
# juvenile
# like
# boo
# radley
#
#
# radically
# weak
# assume
# the
# colonel
# kurt
# 's
# in
# -PRON-
# platoon
# soon
# enough
#
#
# that
# be
# one
# bluff
# call
# ,
# toughen
# the
# searcher
#
#
# stuttering
# ,
# emerge
# ,
# gutter
# urchin
# ,
# burst
#
#
# -PRON-
# live
# for
# the
# moment
# of
# truth
# when
# big
# willy
# rapper
#
#
# acknowledge
# failure
# and
# state
# "
# goddamn
# -PRON-
# shit
# be
# trash
# "
#
#
# "
# -PRON-
# be
# time
# to
# let
# go
# "
# ,
# the
# tin
# man
# bangin
# '
# upon
# -PRON-
# chest
# to
# hear
# the
# echo
#
#
# heartless
# kid
# ,
# hollow
# compartment
#
#
# see
# -PRON-
# the
# people
# of
# the
# united
# ,
# starve
# artistic
#
#
# militia
# keep
# movin
# '
# in
# order
# to
# form
# a
# more
# perfect
# union
#
#
# -PRON-
# be
# cluing
# into
# the
# poison
# panoramic
# brew
# in
# panic
# situation
#
#
# -PRON-
# fuck
# a
# little
# with
# -PRON-
# brittle
# gift
#
#
# -PRON-
# tell
# -PRON-
# "
# stay
# "
# (
# stay
# )
# ...
# up
# high
#
#
# make
# a
# mockery
# of
# sun
# and
# moon
# and
# star
# til
# -PRON-
# hand
# over
# the
# sky
#
#
# -PRON-
# de
# luxe
# be
# ,
# flux
# ,
# pivot
# to
# where
# the
# crux
# be
#
#
# invade
# the
# town
# while
# village
# elder
# holler
# "
# who
# the
# fuck
# be
# this
# ?
# "
#
#
# see
# hip
# cat
# ,
# aggravated
# trudge
# through
# the
# mud
#
#
# quickin
# '
# one
# ,
# plot
# thicken
# like
# ,
# coagulate
# blood
#
#
# rugged
# serpentin
# climb
# ,
# pebble
# to
# rock
#
#
# let
# -PRON-
# pretty
# pink
# cloud
# nine
# expectation
# please
# -PRON-
# not
#
#
# -PRON-
# be
# ,
# ae
# -
# fuckin'-sop
# rock
# ,
# mic
# bizarro
#
#
# proper
# application
# of
# the
# soul
# by
# -PRON-
# standard
#
#
# candid
# once
# position
# from
# which
# instigation
# spawn
#
#
# and
# man
# ,
# -PRON-
# plan
# to
# die
# with
# a
# mic
# in
# -PRON-
# hand
# ,
# -PRON-
# be
# like
# ...
#
#
# abandon
# all
# hope
# yo
# ,
# abandon
# all
# hope
# ,
# -PRON-
# be
# like
#
#
# abandon
# all
# hope
# yo
# ,
# abandon
# all
# hope
# ...

# %%
song_p = nlp(song['lyrics'].tolist()[0])

# %%
doc = song_p
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.is_alpha, token.is_stop)
# Out:
# Aesop aesop PROPN NNP compound Xxxxx True False
# Rock rock PROPN NNP ROOT Xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# Aesop aesop PROPN NNP compound Xxxxx True False
# Rock rock PROPN NNP appos Xxxx True False
# ) ) PUNCT -RRB- punct ) False False
# ... ... PUNCT NFP punct ... False False
# ( ( PUNCT -LRB- punct ( False False
# x16 x16 PROPN NNP ROOT xdd False False
# ) ) PUNCT -RRB- punct ) False False
#
#
#  SPACE
#  False False
# Is be VERB VBZ ROOT Xx True False
# a a DET DT det x True False
# love love NOUN NN nsubj xxxx True False
# such such ADJ JJ amod xxxx True False
# as as ADP IN prep xx True False
# that that DET DT pobj xxxx True False
# which which ADJ WDT dobj xxxx True False
# I -PRON- PRON PRP nsubj X True False
# exhibit exhibit VERB VBP relcl xxxx True False
# for for ADP IN prep xxx True False
# my -PRON- ADJ PRP$ poss xx True False
# practice practice NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# The the DET DT det Xxx True False
# factor factor NOUN NN nsubj xxxx True False
# which which ADJ WDT nsubj xxxx True False
# then then ADV RB advmod xxxx True False
# amalgamates amalgamate VERB VBZ relcl xxxx True False
# debates debate NOUN NNS dobj xxxx True False
# with with ADP IN prep xxxx True False
# straight straight ADJ JJ amod xxxx True False
# - - PUNCT HYPH punct - False False
# jackets jacket NOUN NNS pobj xxxx True False
# and and CCONJ CC cc xxx True False
# ROBES robes PROPN NNP conj XXXX True False
#
#
#  SPACE
#  False False
# Huddled huddle VERB VBD ROOT Xxxxx True False
# in in ADP IN prep xx True False
# brackets bracket NOUN NNS pobj xxxx True False
# that that ADJ WDT nsubj xxxx True False
# blacken blacken VERB VBP relcl xxxx True False
# the the DET DT det xxx True False
# average average ADJ JJ amod xxxx True False
# globe globe NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Xenophobe xenophobe PROPN NNP appos Xxxxx True False
# , , PUNCT , punct , False False
# loathe loathe VERB VB advcl xxxx True False
# to to PART TO aux xx True False
# modify modify VERB VB xcomp xxxx True False
# the the DET DT det xxx True False
# fly fly NOUN NN dobj xxx True False
# , , PUNCT , punct , False False
# feel feel VERB VB dep xxxx True False
# this this DET DT nsubj xxxx True False
# ... ... PUNCT : punct ... False False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# carve carve VERB VBP ROOT xxxx True False
# a a DET DT det x True False
# notch notch NOUN NN dobj xxxx True False
# in in ADP IN prep xx True False
# my -PRON- ADJ PRP$ poss xx True False
# wall wall NOUN NN pobj xxxx True False
# for for ADP IN prep xxx True False
# every every DET DT det xxxx True False
# stall stall NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# every every DET DT det xxxx True False
# fifth fifth ADJ JJ amod xxxx True False
# mark mark NOUN NN nsubj xxxx True False
# slants slant VERB VBZ conj xxxx True False
# diagonal diagonal ADJ JJ acomp xxxx True False
# to to PART TO aux xx True False
# symbolize symbolize VERB VB advcl xxxx True False
# your -PRON- ADJ PRP$ poss xxxx True False
# downfall downfall NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Drunky drunky PROPN NNP compound Xxxxx True False
# peasants peasant NOUN NNS appos xxxx True False
# , , PUNCT , punct , False False
# honor honor VERB VB conj xxxx True False
# the the DET DT det xxx True False
# shifty shifty ADJ JJ amod xxxx True False
# megatron megatron NOUN NN compound xxxx True False
# presence presence NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Slug slug PROPN NNP appos Xxxx True False
# a a DET DT det x True False
# bolt bolt NOUN NN dobj xxxx True False
# once once ADV RB mark xxxx True False
# ceremonies ceremony NOUN NNS nsubj xxxx True False
# of of ADP IN prep xx True False
# merit merit NOUN NN pobj xxxx True False
# turn turn VERB VB advcl xxxx True False
# blood blood NOUN NN compound xxxx True False
# sport sport NOUN NN dobj xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# Uh uh INTJ UH intj Xx True False
# ) ) PUNCT -RRB- punct ) False False
#
#
#  SPACE
#  False False
# Fought fight VERB VBD advcl Xxxxx True False
# in in ADP IN prep xx True False
# hella hella ADJ JJ amod xxxx True False
# high high ADJ JJ amod xxxx True False
# seas sea NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# I -PRON- PRON PRP nsubj X True False
# freeze freeze VERB VBP ROOT xxxx True False
# your -PRON- ADJ PRP$ poss xxxx True False
# mega mega ADJ JJ amod xxxx True False
# dumb dumb ADJ JJ amod xxxx True False
# company company NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Pumpin pumpin PROPN NNP amod Xxxxx True False
# ' ' PUNCT '' punct ' False False
# out out PART RP prt xxx True False
# wise wise ADJ JJ amod xxxx True False
# beads bead NOUN NNS appos xxxx True False
# like like ADP IN prep xxxx True False
# , , PUNCT , punct , False False
# fly fly VERB VB conj xxx True False
# sneak sneak VERB VB compound xxxx True False
# - - PUNCT HYPH punct - False False
# attacks attack NOUN NNS nmod xxxx True False
# on on ADP IN prep xx True False
# dry dry ADJ JJ amod xxx True False
# leaves leaf NOUN NNS pobj xxxx True False
# DUNCE dunce PROPN NNP dobj XXXX True False
#
#
#  SPACE
#  False False
# Crooked crooked ADJ JJ amod Xxxxx True False
# rumors rumor NOUN NNS nsubj xxxx True False
# turn turn VERB VBP ccomp xxxx True False
# zoomers zoomer NOUN NNS dobj xxxx True False
# when when ADV WRB advmod xxxx True False
# rookies rookie NOUN NNS compound xxxx True False
# talkin talkin INTJ UH poss xxxx True False
# ' ' PUNCT '' punct ' False False
#
#
#  SPACE
#  False False
# Bad bad ADJ JJ amod Xxx True False
# seeds seed NOUN NNS nsubj xxxx True False
# blossom blossom VERB VBP advcl xxxx True False
# the the DET DT det xxx True False
# wookie wookie NOUN NN nsubj xxxx True False
# walk walk NOUN NN ccomp xxxx True False
# , , PUNCT , punct , False False
# hawkin hawkin PROPN NNP nsubj xxxx True False
# ' ' PUNCT '' punct ' False False
#
#
#  SPACE
#  False False
# Let let VERB VBP conj Xxx True False
# a a DET DT det x True False
# sucker sucker NOUN NN compound xxxx True False
# drift drift NOUN NN ccomp xxxx True False
# , , PUNCT , punct , False False
# I -PRON- PRON PRP nsubj X True False
# lift lift VERB VBP ROOT xxxx True False
# up up PART RP prt xx True False
# every every DET DT det xxxx True False
# stone stone NOUN NN dobj xxxx True False
# prone prone ADJ JJ amod xxxx True False
# to to PART TO aux xx True False
# find find VERB VB xcomp xxxx True False
#
#
#  SPACE
#  False False
# the the DET DT det xxx True False
# point point NOUN NN dobj xxxx True False
# at at ADP IN prep xx True False
# which which ADJ WDT pobj xxxx True False
# repellent repellent NOUN NN compound xxxx True False
# signals signal NOUN NNS nsubj xxxx True False
# ultimately ultimately ADV RB advmod xxxx True False
# bind bind VERB VBP relcl xxxx True False
#
#
#  SPACE
#  False False
# When when ADV WRB advmod Xxxx True False
# a a DET DT det x True False
# pack pack NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True False
# style style NOUN NN pobj xxxx True False
# mimics mimic NOUN NNS pobj xxxx True False
# see see VERB VBP advcl xxx True False
# my -PRON- ADJ PRP$ poss xx True False
# brans bran NOUN NNS nsubj xxxx True False
# target target VERB VB ccomp xxxx True False
# the the DET DT det xxx True False
# cluster cluster NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# advance advance VERB VBP ROOT xxxx True False
# clutchin clutchin INTJ UH advmod xxxx True False
# ' ' PUNCT '' case ' False False
# the the DET DT det xxx True False
# mic mic NOUN NN appos xxx True False
# like like ADP IN prep xxxx True False
# bully bully NOUN NN pobj xxxx True False
# to to PART TO prep xx True False
# knuckle knuckle VERB VB compound xxxx True False
# duster duster NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# Innocent innocent PROPN NNP advcl Xxxxx True False
# , , PUNCT , punct , False False
# your -PRON- ADJ PRP$ poss xxxx True False
# riddles riddle NOUN NNS nsubj xxxx True False
# yield yield VERB VBP ROOT xxxx True False
# a a DET DT det x True False
# little little ADJ JJ amod xxxx True False
# plastic plastic NOUN NN compound xxxx True False
# blend blend NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Fuck fuck PROPN NNP appos Xxxx True False
# a a DET DT det x True False
# badge badge NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# light light VERB VB conj xxxx True False
# a a DET DT det x True False
# bonfire bonfire NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# dance dance VERB VB conj xxxx True False
# a a DET DT det x True False
# jig jig NOUN NN dobj xxx True False
# around around ADP IN prep xxxx True False
# a a DET DT det x True False
# pig pig NOUN NN pobj xxx True False
#
#
#  SPACE
#  False False
# Figurin figurin PROPN NNP ROOT Xxxxx True False
# ' ' PUNCT '' punct ' False False
# yeah yeah INTJ UH ROOT xxxx True False
# , , PUNCT , punct , False False
# I -PRON- PRON PRP nsubj X True False
# 'll will VERB MD aux 'xx False False
# land land VERB VB ROOT xxxx True False
# a a DET DT det x True False
# plan plan NOUN NN dobj xxxx True False
# on on ADP IN prep xx True False
# bleached bleached ADJ JJ amod xxxx True False
# fame fame NOUN NN compound xxxx True False
# trackers tracker NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# using use VERB VBG acl xxxx True False
# only only ADV RB advmod xxxx True False
# the the DET DT det xxx True False
# finest fine ADJ JJS amod xxxx True False
# i -PRON- PRON PRP nmod x True False
# m be VERB VBP nummod x True False
# post post NOUN NN npadvmod xxxx True False
# - - PUNCT HYPH punct - False False
# modern modern ADJ JJ amod xxxx True False
# terrain terrain NOUN NN compound xxxx True False
# mappers mapper NOUN NNS dobj xxxx True False
#
#
#  SPACE
#  False False
# Once once ADP IN advmod Xxxx True False
# my -PRON- ADJ PRP$ poss xx True False
# brethren brother NOUN NNS nsubj xxxx True False
# disperse disperse VERB VBP ROOT xxxx True False
# ... ... PUNCT NFP punct ... False False
#
#
#  SPACE
#  False False
# My -PRON- ADJ PRP$ poss Xx True False
# God god PROPN NNP npadvmod Xxx True False
# , , PUNCT , punct , False False
# you -PRON- PRON PRP nsubj xxx True False
# think think VERB VBP ROOT xxxx True False
# the the DET DT det xxx True False
# heaven heaven PROPN NNP nsubj xxxx True False
# 's 's PART POS case 'x False False
# touched touch VERB VBD ccomp xxxx True False
# the the DET DT det xxx True False
# earth earth NOUN NN dobj xxxx True False
# then then ADV RB advmod xxxx True False
#  SPACE
#  False False
# Thirstin thirstin PROPN NNP dep Xxxxx True False
# ' ' PART POS case ' False False
# a a DET DT det x True False
# perch perch NOUN NN dobj xxxx True False
# on on ADP IN prep xx True False
# a a DET DT det x True False
# bursted burst VERB VBN amod xxxx True False
# curse curse NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# But but CCONJ CC cc Xxx True False
# I -PRON- PRON PRP nsubj X True False
# do do VERB VBP aux xx True False
# n't not ADV RB neg x'x False False
# confide confide VERB VB ROOT xxxx True False
# wine wine NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True False
# water water NOUN NN conj xxxx True False
# chose choose VERB VBD conj xxxx True False
# me -PRON- PRON PRP dobj xx True False
#
#
#  SPACE
#  False False
# Bored bored ADJ JJ nsubj Xxxxx True False
# , , PUNCT , punct , False False
# lasso lasso VERB VB ccomp xxxx True False
# down down PART RP prt xxxx True False
# Polaris polaris PROPN NNPS dobj Xxxxx True False
# , , PUNCT , punct , False False
# let let VERB VB ROOT xxx True False
# the the DET DT det xxx True False
# glow glow NOUN NN nsubj xxxx True False
# amuse amuse VERB VB ccomp xxxx True False
# me -PRON- PRON PRP dobj xx True False
#
#
#  SPACE
#  False False
# OK ok INTJ UH intj XX True False
# I -PRON- PRON PRP nsubj X True False
# lay lie VERB VBD ROOT xxx True False
# me -PRON- PRON PRP dobj xx True False
# down down PART RP prt xxxx True False
# to to ADP IN aux xx True False
# sleep sleep NOUN NN advcl xxxx True False
# , , PUNCT , punct , False False
# creepin creepin NOUN NN conj xxxx True False
# ' ' PUNCT '' case ' False False
# a a DET DT det x True False
# slumber slumber NOUN NN dobj xxxx True False
# under under ADP IN prep xxxx True False
# red red ADJ JJ amod xxx True False
# skies sky NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# Heads head NOUN NNS compound Xxxxx True False
# splittin splittin VERB VBP ROOT xxxx True False
# ' ' PUNCT '' punct ' False False
# , , PUNCT , punct , False False
# straight straight ADV RB amod xxxx True False
# sippin sippin ADV RB appos xxxx True False
# ' ' PUNCT '' punct ' False False
# a a DET DT det x True False
# drip drip NOUN NN appos xxxx True False
# of of ADP IN prep xx True False
# dead dead ADJ JJ amod xxxx True False
# vibes vibe NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# It -PRON- PRON PRP nsubj Xx True False
# 's be VERB VBZ ROOT 'x False False
# red red ADJ JJ amod xxx True False
# tides tide NOUN NNS attr xxxx True False
# from from ADP IN prep xxxx True False
# here here ADV RB pcomp xxxx True False
# , , PUNCT , punct , False False
# stop stop VERB VB conj xxxx True False
# and and CCONJ CC cc xxx True False
# smell smell VERB VBP conj xxxx True False
# analog analog NOUN NN amod xxxx True False
# hell hell NOUN NN npadvmod xxxx True False
#
#
#  SPACE
#  False False
# Clenchin clenchin PROPN NNP poss Xxxxx True False
# ' ' PUNCT '' case ' False False
# a a DET DT det x True False
# stench stench NOUN NN ROOT xxxx True False
# of of ADP IN prep xx True False
# burnin burnin NOUN NN poss xxxx True False
# ' ' PUNCT '' case ' False False
# logics logic NOUN NNS pobj xxxx True False
# and and CCONJ CC cc xxx True False
# a a DET DT det x True False
# child child NOUN NN conj xxxx True False
# with with ADP IN prep xxxx True False
# yearning yearn VERB VBG pcomp xxxx True False
#
#
#  SPACE
#  False False
# optics optic NOUN NNS dobj xxxx True False
# ... ... PUNCT : punct ... False False
#
#
#  SPACE
#  False False
# Now now ADV RB advmod Xxx True False
# someone someone NOUN NN nsubjpass xxxx True False
# 's be VERB VBZ auxpass 'x False False
# approached approach VERB VBN ROOT xxxx True False
# the the DET DT det xxx True False
# ropes rope NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# shaking shake VERB VBG advcl xxxx True False
# like like ADP IN prep xxxx True False
# snow snow NOUN NN compound xxxx True False
# - - PUNCT HYPH punct - False False
# globes globe NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# Others others PROPN NNPS nsubj Xxxxx True False
# sought seek VERB VBD ccomp xxxx True False
# safety safety NOUN NN dobj xxxx True False
# in in ADP IN prep xx True False
# numbers number NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# other other ADJ JJ poss xxxx True False
# 's 's PART POS case 'x False False
# flows flow NOUN NNS nsubjpass xxxx True False
# got get VERB VBD auxpass xxx True False
# towed tow VERB VBN ROOT xxxx True False
# under under ADP IN prep xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# yeah yeah INTJ UH intj xxxx True False
# ) ) PUNCT -RRB- punct ) False False
#
#
#  SPACE
#  False False
# Still still ADV RB advmod Xxxxx True False
# another another DET DT nsubj xxxx True False
# took take VERB VBD ROOT xxxx True False
# a a DET DT det x True False
# turn turn NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True False
# crashed crash VERB VBD conj xxxx True False
# and and CCONJ CC cc xxx True False
# burned burn VERB VBD conj xxxx True False
# while while ADP IN mark xxxx True False
# others other NOUN NNS nsubj xxxx True False
# flee flee VERB VBP advcl xxxx True False
#
#
#  SPACE
#  False False
# But but CCONJ CC cc Xxx True False
# there there ADV EX expl xxxx True False
# will will VERB MD aux xxxx True False
# never never ADV RB neg xxxx True False
# be be VERB VB conj xx True False
# another another DET DT det xxxx True False
# starvin starvin NOUN NN poss xxxx True False
# ' ' PUNCT '' case ' False False
# marvel marvel NOUN NN attr xxxx True False
# like like ADP IN prep xxxx True False
# me -PRON- PRON PRP pobj xx True False
#
#
#  SPACE
#  False False
# See see VERB VB intj Xxx True False
# , , PUNCT , punct , False False
# there there ADV EX expl xxxx True False
# 's be VERB VBZ ROOT 'x False False
# a a DET DT det x True False
# time time NOUN NN attr xxxx True False
# when when ADV WRB advmod xxxx True False
# ... ... PUNCT : punct ... False False
# rhymin rhymin INTJ UH attr xxxx True False
# ' ' PUNCT '' punct ' False False
# ... ... PUNCT : punct ... False False
#
#
#  SPACE
#  False False
# Pain pain NOUN NN nsubj Xxxx True False
# combined combine VERB VBN acl xxxx True False
# ca can VERB MD aux xx True False
# n't not ADV RB neg x'x False False
# even even ADV RB advmod xxxx True False
# manage manage VERB VB ROOT xxxx True False
# to to PART TO aux xx True False
# tell tell VERB VB xcomp xxxx True False
# what what NOUN WP attr xxxx True False
# the the DET DT det xxx True False
# swell swell NOUN NN nsubj xxxx True False
# is be VERB VBZ ccomp xx True False
# , , PUNCT , punct , False False
# like like ADP IN prep xxxx True False
#
#
#  SPACE
#  False False
# Picture picture NOUN NN pobj Xxxxx True False
# your -PRON- ADJ PRP$ poss xxxx True False
# imagery imagery NOUN NN nsubj xxxx True False
# embellished embellish VERB VBN acl xxxx True False
# with with ADP IN prep xxxx True False
# the the DET DT det xxx True False
# hellish hellish ADJ JJ amod xxxx True False
# aspects aspect NOUN NNS pobj xxxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# swans swan NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# for for ADP IN prep xxx True False
# lone lone ADJ JJ amod xxxx True False
# facets facet NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# Soul soul PROPN NNP nsubj Xxxx True False
# crafted craft VERB VBD ROOT xxxx True False
# fat fat ADJ JJ amod xxx True False
# cats cat NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# burrowin burrowin NOUN NN dep xxxx True False
# ' ' PUNCT '' punct ' False False
# , , PUNCT , punct , False False
# left leave VERB VBD amod xxxx True False
# perrenial perrenial ADJ JJ amod xxxx True False
# tenants tenant NOUN NNS nsubj xxxx True False
# discouraged discourage VERB VBN conj xxxx True False
# in in ADP IN prep xx True False
#
#
#  SPACE
#  False False
# Discussin discussin PROPN NNP poss Xxxxx True False
# ' ' PART POS case ' False False
# my -PRON- ADJ PRP$ poss xx True False
# foresees foresee NOUN NNS pobj xxxx True False
# and and CCONJ CC cc xxx True False
# flourishing flourish VERB VBG conj xxxx True False
# , , PUNCT , punct , False False
# Uh uh INTJ UH intj Xx True False
# ! ! PUNCT . punct ! False False
#
#
#  SPACE
#  False False
# Searching search VERB VBG ROOT Xxxxx True False
# , , PUNCT , punct , False False
# perching perching ADJ JJ conj xxxx True False
# , , PUNCT , punct , False False
# poetic poetic ADJ JJ amod xxxx True False
# lead lead NOUN NN compound xxxx True False
# poison poison NOUN NN appos xxxx True False
#
#
#  SPACE
#  False False
# Poised poised PROPN NNP nsubj Xxxxx True False
# , , PUNCT , punct , False False
# imploised implois VERB VBD ROOT xxxx True False
# to to PART TO aux xx True False
# leak leak VERB VB xcomp xxxx True False
# a a DET DT det x True False
# little little ADJ JJ amod xxxx True False
# bit bit NOUN NN dobj xxx True False
# of of ADP IN prep xx True False
# boisture boisture NOUN NN pobj xxxx True False
# on on ADP IN prep xx True False
# your -PRON- ADJ PRP$ poss xxxx True False
# pride pride NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# 'm be VERB VBP ROOT 'x False False
# a a DET DT det x True False
# , , PUNCT , punct , False False
# animated animated ADJ JJ amod xxxx True False
# style style NOUN NN compound xxxx True False
# machine machine NOUN NN attr xxxx True False
# in in ADP IN prep xx True False
#
#
#  SPACE
#  False False
# a a DET DT det x True False
# veening veen VERB VBG amod xxxx True False
# faulty faulty ADJ JJ amod xxxx True False
# production production NOUN NN appos xxxx True False
# fueled fuel VERB VBN acl xxxx True False
# by by ADP IN agent xx True False
# nicotine nicotine NOUN NN compound xxxx True False
# suction suction NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# From from ADP IN prep Xxxx True False
# tux tux NOUN NN pobj xxx True False
# in in ADP IN prep xx True False
# my -PRON- ADJ PRP$ poss xx True False
# carnivore carnivore NOUN NN pobj xxxx True False
# to to ADP IN prep xx True False
# vipers viper NOUN NNS pobj xxxx True False
# in in ADP IN prep xx True False
# my -PRON- ADJ PRP$ poss xx True False
# garden garden NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# You -PRON- PRON PRP nsubj Xxx True False
# flash flash VERB VBP ROOT xxxx True False
# identify identify NOUN NN xcomp xxxx True False
# by by ADP IN agent xx True False
# the the DET DT det xxx True False
# genus genus NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# species specie NOUN NNS conj xxxx True False
# and and CCONJ CC cc xxx True False
# class class NOUN NN conj xxxx True False
#
#
#  SPACE
#  False False
# Start start VERB VBP dobj Xxxxx True False
# to to PART TO aux xx True False
# chuckle chuckle VERB VB advcl xxxx True False
#
#
#  SPACE
#  False False
# Buckle buckle PROPN NNP dobj Xxxxx True False
# the the DET DT det xxx True False
# architecture architecture NOUN NN dobj xxxx True False
# until until ADP IN mark xxxx True False
# it -PRON- PRON PRP nsubj xx True False
# fell fall VERB VBD advcl xxxx True False
# through through ADP IN prep xxxx True False
#
#
#  SPACE
#  False False
# Kill kill PROPN NNP pobj Xxxx True False
# the the DET DT det xxx True False
# survivors survivor NOUN NNS nsubj xxxx True False
# then then ADV RB advmod xxxx True False
# raise raise VERB VBP conj xxxx True False
# the the DET DT det xxx True False
# dead dead ADJ JJ dobj xxxx True False
# for for ADP IN prep xxx True False
# shock shock NOUN NN compound xxxx True False
# value value NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# By by ADP IN prep Xx True False
# the the DET DT det xxx True False
# time time NOUN NN pobj xxxx True False
# the the DET DT det xxx True False
# pending pend VERB VBG amod xxxx True False
# settlements settlement NOUN NNS nsubj xxxx True False
# fully fully ADV RB advmod xxxx True False
# negotiated negotiate VERB VBD relcl xxxx True False
# ( ( PUNCT -LRB- punct ( False False
# yeah yeah INTJ UH ROOT xxxx True False
# I -PRON- PRON PRP nsubj X True False
# 'll will VERB MD ROOT 'xx False False
# ... ... PUNCT . punct ... False False
# ) ) PUNCT -RRB- punct ) False False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# 'll will VERB MD aux 'xx False False
# have have VERB VB aux xxxx True False
# put put VERB VBN ROOT xxx True False
# a a DET DT det x True False
# sonic sonic ADJ JJ amod xxxx True False
# youth youth NOUN NN dobj xxxx True False
# to to PART TO aux xx True False
# get get VERB VB advcl xxx True False
# myself -PRON- PRON PRP nsubj xxxx True False
# situated situate VERB VBN ccomp xxxx True False
#
#
#  SPACE
#  False False
# It -PRON- PRON PRP nsubj Xx True False
# 's be VERB VBZ ROOT 'x False False
# like like INTJ UH intj xxxx True False
# sadly sadly ADV RB advmod xxxx True False
# , , PUNCT , punct , False False
# my -PRON- ADJ PRP$ poss xx True False
# style style NOUN NN nsubj xxxx True False
# spooks spook NOUN NNS compound xxxx True False
# juveniles juvenile NOUN NNS attr xxxx True False
# like like ADP IN prep xxxx True False
# Boo boo PROPN NNP compound Xxx True False
# Radley radley PROPN NNP pobj Xxxxx True False
#
#
#  SPACE
#  False False
# Radically radically ADV RB advmod Xxxxx True False
# weak weak ADJ JJ amod xxxx True False
# assume assume VERB VBP ROOT xxxx True False
# the the DET DT det xxx True False
# Colonel colonel PROPN NNP compound Xxxxx True False
# Kurt kurt PROPN NNP dobj Xxxx True False
# 's 's PART POS case 'x False False
# in in ADP IN prep xx True False
# our -PRON- ADJ PRP$ poss xxx True False
# platoon platoon NOUN NN pobj xxxx True False
# soon soon ADV RB advmod xxxx True False
# enough enough ADV RB npadvmod xxxx True False
#
#
#  SPACE
#  False False
# That that DET DT nsubj Xxxx True False
# 's be VERB VBZ ccomp 'x False False
# one one NUM CD nummod xxx True False
# bluff bluff NOUN NN compound xxxx True False
# call call NOUN NN attr xxxx True False
# , , PUNCT , punct , False False
# toughens toughen VERB VBZ ROOT xxxx True False
# the the DET DT det xxx True False
# searcher searcher NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Stuttering stuttering PROPN NNP dobj Xxxxx True False
# , , PUNCT , punct , False False
# emerging emerge VERB VBG amod xxxx True False
# , , PUNCT , punct , False False
# gutter gutter NOUN NN compound xxxx True False
# urchin urchin NOUN NN conj xxxx True False
# , , PUNCT , punct , False False
# bursting burst VERB VBG advcl xxxx True False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# live live VERB VBP ROOT xxxx True False
# for for ADP IN prep xxx True False
# the the DET DT det xxx True False
# moment moment NOUN NN pobj xxxx True False
# of of ADP IN prep xx True False
# truth truth NOUN NN pobj xxxx True False
# when when ADV WRB advmod xxxx True False
# Big big ADJ JJ compound Xxx True False
# Willy willy PROPN NNP compound Xxxxx True False
# rapper rapper NOUN NN nsubj xxxx True False
#
#
#  SPACE
#  False False
# acknowledges acknowledge VERB VBZ advcl xxxx True False
# failure failure NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True False
# states state NOUN NNS conj xxxx True False
# " " PUNCT `` punct " False False
# Goddamn goddamn ADJ JJ nsubj Xxxxx True False
# my -PRON- ADJ PRP$ poss xx True False
# shit shit NOUN NN nsubj xxxx True False
# is be VERB VBZ aux xx True False
# trash trash NOUN NN ROOT xxxx True False
# " " PUNCT `` punct " False False
#
#
#  SPACE
#  False False
# " " PUNCT '' punct " False False
# It -PRON- PRON PRP nsubj Xx True False
# 's be VERB VBZ ROOT 'x False False
# time time NOUN NN attr xxxx True False
# to to PART TO aux xx True False
# let let VERB VB relcl xxx True False
# go go VERB VB xcomp xx True False
# " " PUNCT '' punct " False False
# , , PUNCT , punct , False False
# the the DET DT det xxx True False
# tin tin NOUN NN compound xxx True False
# man man NOUN NN nsubj xxx True False
# bangin bangin VERB VBG acomp xxxx True False
# ' ' PUNCT '' punct ' False False
# upon upon ADP IN prep xxxx True False
# his -PRON- ADJ PRP$ poss xxx True False
# chest chest NOUN NN pobj xxxx True False
# to to PART TO aux xx True False
# hear hear VERB VB advcl xxxx True False
# the the DET DT det xxx True False
# echo echo NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Heartless heartless ADJ JJ amod Xxxxx True False
# kid kid NOUN NN appos xxx True False
# , , PUNCT , punct , False False
# hollow hollow ADJ JJ amod xxxx True False
# compartments compartment NOUN NNS dobj xxxx True False
#
#
#  SPACE
#  False False
# See see VERB VBP ROOT Xxx True False
# we -PRON- PRON PRP dobj xx True False
# the the DET DT det xxx True False
# people people NOUN NNS appos xxxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# united united ADJ JJ pobj xxxx True False
# , , PUNCT , punct , False False
# starving starve VERB VBG csubj xxxx True False
# artistic artistic ADJ JJ amod xxxx True False
#
#
#  SPACE
#  False False
# Militia militia PROPN NNP dobj Xxxxx True False
# keep keep VERB VB conj xxxx True False
# movin movin NOUN NN oprd xxxx True False
# ' ' PUNCT '' punct ' False False
# in in ADP IN prep xx True False
# order order NOUN NN pobj xxxx True False
# to to PART TO aux xx True False
# form form VERB VB acl xxxx True False
# a a DET DT det x True False
# more more ADV RBR advmod xxxx True False
# perfect perfect ADJ JJ amod xxxx True False
# union union NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# 'm be VERB VBP aux 'x False False
# cluing cluing ADJ JJ ROOT xxxx True False
# into into ADP IN prep xxxx True False
# the the DET DT det xxx True False
# poison poison NOUN NN compound xxxx True False
# panoramics panoramic NOUN NNS pobj xxxx True False
# brewed brew VERB VBN acl xxxx True False
# in in ADP IN prep xx True False
# panic panic NOUN NN compound xxxx True False
# situations situation NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# It -PRON- PRON PRP nsubj Xx True False
# fucks fuck VERB VBZ ROOT xxxx True False
# a a DET DT det x True False
# little little ADJ JJ npadvmod xxxx True False
# with with ADP IN prep xxxx True False
# my -PRON- ADJ PRP$ poss xx True False
# brittle brittle ADJ JJ amod xxxx True False
# gift gift NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# tell tell VERB VBP ROOT xxxx True False
# myself -PRON- PRON PRP dobj xxxx True False
# " " PUNCT `` punct " False False
# Stay stay VERB VB xcomp Xxxx True False
# " " PUNCT '' punct " False False
# ( ( PUNCT -LRB- punct ( False False
# Stay stay VERB VB dep Xxxx True False
# ) ) PUNCT -RRB- punct ) False False
# ... ... PUNCT NFP punct ... False False
# up up PART RP advmod xx True False
# high high ADJ JJ ROOT xxxx True False
#
#
#  SPACE
#  False False
# make make VERB VBP conj xxxx True False
# a a DET DT det x True False
# mockery mockery NOUN NN dobj xxxx True False
# of of ADP IN prep xx True False
# Sun sun PROPN NNP pobj Xxx True False
# and and CCONJ CC cc xxx True False
# moon moon NOUN NN conj xxxx True False
# and and CCONJ CC cc xxx True False
# star star NOUN NN conj xxxx True False
# til til ADP IN mark xxx True False
# they -PRON- PRON PRP nsubj xxxx True False
# hand hand VERB VBP advcl xxxx True False
# over over PART RP prt xxxx True False
# the the DET DT det xxx True False
# sky sky NOUN NN dobj xxx True False
#
#
#  SPACE
#  False False
# My -PRON- ADJ PRP$ poss Xx True False
# de de PROPN NNP nmod xx True False
# luxe luxe NOUN NN nsubj xxxx True False
# is be VERB VBZ ROOT xx True False
# , , PUNCT , punct , False False
# fluxes flux NOUN NNS attr xxxx True False
# , , PUNCT , punct , False False
# pivots pivot NOUN NNS attr xxxx True False
# to to ADP IN prep xx True False
# where where ADV WRB advmod xxxx True False
# the the DET DT det xxx True False
# crux crux NOUN NN nsubj xxxx True False
# is be VERB VBZ pcomp xx True False
#
#
#  SPACE
#  False False
# Invade invade PROPN NNP xcomp Xxxxx True False
# the the DET DT det xxx True False
# town town NOUN NN dobj xxxx True False
# while while ADP IN mark xxxx True False
# village village NOUN NN compound xxxx True False
# elders elder NOUN NNS nsubj xxxx True False
# holler holler VERB VBP advcl xxxx True False
# " " PUNCT `` punct " False False
# Who who NOUN WP dobj Xxx True False
# the the DET DT det xxx True False
# fuck fuck NOUN NN poss xxxx True False
# 's be VERB VBZ case 'x False False
# this this DET DT dobj xxxx True False
# ? ? PUNCT . punct ? False False
# " " PUNCT `` punct " False False
#
#
#  SPACE
#  False False
# See see PROPN NNP advcl Xxx True False
# hipper hip ADJ JJR amod xxxx True False
# cats cat NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# aggravated aggravated ADJ JJ amod xxxx True False
# trudge trudge NOUN NN appos xxxx True False
# through through ADP IN prep xxxx True False
# the the DET DT det xxx True False
# muds mud NOUN NNS pobj xxxx True False
#
#
#  SPACE
#  False False
# Quickin quickin PROPN NNP poss Xxxxx True False
# ' ' PART POS case ' False False
# ones one NOUN NNS appos xxxx True False
# , , PUNCT , punct , False False
# plots plot NOUN NNS nsubj xxxx True False
# thicken thicken VERB VBP ROOT xxxx True False
# like like INTJ UH prep xxxx True False
# , , PUNCT , punct , False False
# coagulated coagulate VERB VBD amod xxxx True False
# blood blood NOUN NN dobj xxxx True False
#
#
#  SPACE
#  False False
# Rugged rugged PROPN NNP amod Xxxxx True False
# serpentines serpentin VERB VBZ compound xxxx True False
# climb climb NOUN NN relcl xxxx True False
# , , PUNCT , punct , False False
# pebble pebble NOUN NN amod xxxx True False
# to to ADP IN prep xx True False
# rock rock NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# Let let VERB VB ROOT Xxx True False
# your -PRON- ADJ PRP$ poss xxxx True False
# pretty pretty ADV RB advmod xxxx True False
# pink pink ADJ JJ amod xxxx True False
# cloud cloud NOUN NN nsubj xxxx True False
# nine nine NUM CD nummod xxxx True False
# expectations expectation NOUN NNS nsubj xxxx True False
# please please VERB VBP ccomp xxxx True False
# you -PRON- PRON PRP dobj xxx True False
# not not ADV RB neg xxx True False
#
#
#  SPACE
#  False False
# I -PRON- PRON PRP nsubj X True False
# 'm be VERB VBP ROOT 'x False False
# , , PUNCT , punct , False False
# Ae ae PROPN NNP nmod Xx True False
# - - PUNCT HYPH punct - False False
# fuckin'-sop fuckin'-sop PROPN NNP attr xxxx'-xxx False False
# Rock rock PROPN NNP nmod Xxxx True False
# , , PUNCT , punct , False False
# mic mic PROPN NNP amod xxx True False
# bizarro bizarro NOUN NN conj xxxx True False
#
#
#  SPACE
#  False False
# Proper proper PROPN NNP amod Xxxxx True False
# application application NOUN NN ROOT xxxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# soul soul NOUN NN pobj xxxx True False
# by by ADP IN prep xx True False
# my -PRON- ADJ PRP$ poss xx True False
# standard standard NOUN NN pobj xxxx True False
#
#
#  SPACE
#  False False
# Candid candid VERB VBD amod Xxxxx True False
# once once ADV RB advmod xxxx True False
# position position NOUN NN npadvmod xxxx True False
# from from ADP IN prep xxxx True False
# which which ADJ WDT pobj xxxx True False
# instigations instigation NOUN NNS nsubj xxxx True False
# spawn spawn VERB VBP relcl xxxx True False
#
#
#  SPACE
#  False False
# And and CCONJ CC cc Xxx True False
# man man NOUN NN conj xxx True False
# , , PUNCT , punct , False False
# I -PRON- PRON PRP nsubj X True False
# plan plan VERB VBP ROOT xxxx True False
# to to PART TO aux xx True False
# die die VERB VB xcomp xxx True False
# with with ADP IN prep xxxx True False
# a a DET DT det x True False
# mic mic NOUN NN pobj xxx True False
# in in ADP IN prep xx True False
# my -PRON- ADJ PRP$ poss xx True False
# hand hand NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# it -PRON- PRON PRP nsubj xx True False
# 's be VERB VBZ ROOT 'x False False
# like like ADP IN intj xxxx True False
# ... ... PUNCT NFP punct ... False False
#
#
#  SPACE
#  False False
# Abandon abandon VERB VBP advcl Xxxxx True False
# all all DET DT det xxx True False
# hope hope VERB VBP dobj xxxx True False
# yo yo INTJ UH dobj xx True False
# , , PUNCT , punct , False False
# abandon abandon VERB VB ROOT xxxx True False
# all all DET DT det xxx True False
# hope hope NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# it -PRON- PRON PRP nsubj xx True False
# 's be VERB VBZ ROOT 'x False False
# like like ADP IN intj xxxx True False
#
#
#  SPACE
#  False False
# Abandon abandon VERB VBP advcl Xxxxx True False
# all all DET DT det xxx True False
# hope hope VERB VBP dobj xxxx True False
# yo yo INTJ UH dobj xx True False
# , , PUNCT , punct , False False
# abandon abandon VERB VB ROOT xxxx True False
# all all DET DT det xxx True False
# hope hope NOUN NN dobj xxxx True False
# ... ... PUNCT . punct ... False False

# %%
foo = markovify.NewlineText(song['lyrics'].tolist()[0])

# %%
help(foo.chain)
# Out:
# Help on Chain in module markovify.chain object:
#
# class Chain(builtins.object)
#  |  A Markov chain representing processes that have both beginnings and ends.
#  |  For example: Sentences.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, corpus, state_size, model=None)
#  |      `corpus`: A list of lists, where each outer list is a "run"
#  |      of the process (e.g., a single sentence), and each inner list
#  |      contains the steps (e.g., words) in the run. If you want to simulate
#  |      an infinite process, you can come very close by passing just one, very
#  |      long run.
#  |
#  |      `state_size`: An integer indicating the number of items the model
#  |      uses to represent its state. For text generation, 2 or 3 are typical.
#  |
#  |  build(self, corpus, state_size)
#  |      Build a Python representation of the Markov model. Returns a dict
#  |      of dicts where the keys of the outer dict represent all possible states,
#  |      and point to the inner dicts. The inner dicts represent all possibilities
#  |      for the "next" item in the chain, along with the count of times it
#  |      appears.
#  |
#  |  gen(self, init_state=None)
#  |      Starting either with a naive BEGIN state, or the provided `init_state`
#  |      (as a tuple), return a generator that will yield successive items
#  |      until the chain reaches the END state.
#  |
#  |  move(self, state)
#  |      Given a state, choose the next item at random.
#  |
#  |  precompute_begin_state(self)
#  |      Caches the summation calculation and available choices for BEGIN * state_size.
#  |      Significantly speeds up chain generation on large corpuses. Thanks, @schollz!
#  |
#  |  to_json(self)
#  |      Dump the model as a JSON object, for loading later.
#  |
#  |  walk(self, init_state=None)
#  |      Return a list representing a single run of the Markov model, either
#  |      starting with a naive BEGIN state, or the provided `init_state`
#  |      (as a tuple).
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  from_json(json_thing) from builtins.type
#  |      Given a JSON object or JSON string that was created by `self.to_json`,
#  |      return the corresponding markovify.Chain.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
dir(song_p.vocab)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_reset_cache',
#  'add_flag',
#  'cfg',
#  'data_dir',
#  'from_bytes',
#  'from_disk',
#  'get_vector',
#  'has_vector',
#  'lang',
#  'length',
#  'lex_attr_getters',
#  'lexemes_from_bytes',
#  'lexemes_to_bytes',
#  'morphology',
#  'prune_vectors',
#  'reset_vectors',
#  'set_vector',
#  'strings',
#  'to_bytes',
#  'to_disk',
#  'vectors',
#  'vectors_length']

# %%
len([i for i in song_p.vocab.strings if i.isalpha])
# Out:
# 1482099

# %%
dir(song_p)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '_bulk_merge',
#  '_py_tokens',
#  '_realloc',
#  '_vector',
#  '_vector_norm',
#  'cats',
#  'char_span',
#  'count_by',
#  'doc',
#  'ents',
#  'extend_tensor',
#  'from_array',
#  'from_bytes',
#  'from_disk',
#  'get_extension',
#  'get_lca_matrix',
#  'has_extension',
#  'has_vector',
#  'is_parsed',
#  'is_sentenced',
#  'is_tagged',
#  'mem',
#  'merge',
#  'noun_chunks',
#  'noun_chunks_iterator',
#  'print_tree',
#  'remove_extension',
#  'retokenize',
#  'sentiment',
#  'sents',
#  'set_extension',
#  'similarity',
#  'tensor',
#  'text',
#  'text_with_ws',
#  'to_array',
#  'to_bytes',
#  'to_disk',
#  'user_data',
#  'user_hooks',
#  'user_span_hooks',
#  'user_token_hooks',
#  'vector',
#  'vector_norm',
#  'vocab']

# %%
from tensorflow.contrib import rnn

# %%
help(rnn.)
# Out:
# Help on class BidirectionalGridLSTMCell in module tensorflow.contrib.rnn.python.ops.rnn_cell:
#
# class BidirectionalGridLSTMCell(GridLSTMCell)
#  |  Bidirectional GridLstm cell.
#  |
#  |  The bidirection connection is only used in the frequency direction, which
#  |  hence doesn't affect the time direction's real-time processing that is
#  |  required for online recognition systems.
#  |  The current implementation uses different weights for the two directions.
#  |
#  |  Method resolution order:
#  |      BidirectionalGridLSTMCell
#  |      GridLSTMCell
#  |      tensorflow.python.ops.rnn_cell_impl.RNNCell
#  |      tensorflow.python.layers.base.Layer
#  |      tensorflow.python.keras.engine.base_layer.Layer
#  |      tensorflow.python.training.checkpointable.base.CheckpointableBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, num_units, use_peepholes=False, share_time_frequency_weights=False, cell_clip=None, initializer=None, num_unit_shards=1, forget_bias=1.0, feature_size=None, frequency_skip=None, num_frequency_blocks=None, start_freqindex_list=None, end_freqindex_list=None, couple_input_forget_gates=False, backward_slice_offset=0, reuse=None)
#  |      Initialize the parameters for an LSTM cell.
#  |
#  |      Args:
#  |        num_units: int, The number of units in the LSTM cell
#  |        use_peepholes: (optional) bool, default False. Set True to enable
#  |          diagonal/peephole connections.
#  |        share_time_frequency_weights: (optional) bool, default False. Set True to
#  |          enable shared cell weights between time and frequency LSTMs.
#  |        cell_clip: (optional) A float value, default None, if provided the cell
#  |          state is clipped by this value prior to the cell output activation.
#  |        initializer: (optional) The initializer to use for the weight and
#  |          projection matrices, default None.
#  |        num_unit_shards: (optional) int, default 1, How to split the weight
#  |          matrix. If > 1, the weight matrix is stored across num_unit_shards.
#  |        forget_bias: (optional) float, default 1.0, The initial bias of the
#  |          forget gates, used to reduce the scale of forgetting at the beginning
#  |          of the training.
#  |        feature_size: (optional) int, default None, The size of the input feature
#  |          the LSTM spans over.
#  |        frequency_skip: (optional) int, default None, The amount the LSTM filter
#  |          is shifted by in frequency.
#  |        num_frequency_blocks: [required] A list of frequency blocks needed to
#  |          cover the whole input feature splitting defined by start_freqindex_list
#  |          and end_freqindex_list.
#  |        start_freqindex_list: [optional], list of ints, default None,  The
#  |          starting frequency index for each frequency block.
#  |        end_freqindex_list: [optional], list of ints, default None. The ending
#  |          frequency index for each frequency block.
#  |        couple_input_forget_gates: (optional) bool, default False, Whether to
#  |          couple the input and forget gates, i.e. f_gate = 1.0 - i_gate, to reduce
#  |          model parameters and computation cost.
#  |        backward_slice_offset: (optional) int32, default 0, the starting offset to
#  |          slice the feature for backward processing.
#  |        reuse: (optional) Python boolean describing whether to reuse variables
#  |          in an existing scope.  If not `True`, and the existing scope already has
#  |          the given variables, an error is raised.
#  |
#  |  call(self, inputs, state)
#  |      Run one step of LSTM.
#  |
#  |      Args:
#  |        inputs: input Tensor, 2D, [batch, num_units].
#  |        state: tuple of Tensors, 2D, [batch, state_size].
#  |
#  |      Returns:
#  |        A tuple containing:
#  |        - A 2D, [batch, output_dim], Tensor representing the output of the LSTM
#  |          after reading "inputs" when previous state was "state".
#  |          Here output_dim is num_units.
#  |        - A 2D, [batch, state_size], Tensor representing the new state of LSTM
#  |          after reading "inputs" when previous state was "state".
#  |      Raises:
#  |        ValueError: if an input_size was specified and the provided inputs have
#  |          a different dimension.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from GridLSTMCell:
#  |
#  |  output_size
#  |      Integer or TensorShape: size of outputs produced by this cell.
#  |
#  |  state_size
#  |      size(s) of state(s) used by this cell.
#  |
#  |      It can be represented by an Integer, a TensorShape or a tuple of Integers
#  |      or TensorShapes.
#  |
#  |  state_tuple_type
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from tensorflow.python.ops.rnn_cell_impl.RNNCell:
#  |
#  |  __call__(self, inputs, state, scope=None)
#  |      Run this RNN cell on inputs, starting from the given state.
#  |
#  |      Args:
#  |        inputs: `2-D` tensor with shape `[batch_size, input_size]`.
#  |        state: if `self.state_size` is an integer, this should be a `2-D Tensor`
#  |          with shape `[batch_size, self.state_size]`.  Otherwise, if
#  |          `self.state_size` is a tuple of integers, this should be a tuple
#  |          with shapes `[batch_size, s] for s in self.state_size`.
#  |        scope: VariableScope for the created subgraph; defaults to class name.
#  |
#  |      Returns:
#  |        A pair containing:
#  |
#  |        - Output: A `2-D` tensor with shape `[batch_size, self.output_size]`.
#  |        - New state: Either a single `2-D` tensor, or a tuple of tensors matching
#  |          the arity and shapes of `state`.
#  |
#  |  build(self, _)
#  |      Creates the variables of the layer.
#  |
#  |  get_initial_state(self, inputs=None, batch_size=None, dtype=None)
#  |
#  |  zero_state(self, batch_size, dtype)
#  |      Return zero-filled state tensor(s).
#  |
#  |      Args:
#  |        batch_size: int, float, or unit Tensor representing the batch size.
#  |        dtype: the data type to use for the state.
#  |
#  |      Returns:
#  |        If `state_size` is an int or TensorShape, then the return value is a
#  |        `N-D` tensor of shape `[batch_size, state_size]` filled with zeros.
#  |
#  |        If `state_size` is a nested list or tuple, then the return value is
#  |        a nested list or tuple (of the same structure) of `2-D` tensors with
#  |        the shapes `[batch_size, s]` for each s in `state_size`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from tensorflow.python.layers.base.Layer:
#  |
#  |  __deepcopy__(self, memo)
#  |
#  |  add_loss(self, losses, inputs=None)
#  |      Add loss tensor(s), potentially dependent on layer inputs.
#  |
#  |      Some losses (for instance, activity regularization losses) may be dependent
#  |      on the inputs passed when calling a layer. Hence, when reusing the same
#  |      layer on different inputs `a` and `b`, some entries in `layer.losses` may
#  |      be dependent on `a` and some on `b`. This method automatically keeps track
#  |      of dependencies.
#  |
#  |      The `get_losses_for` method allows to retrieve the losses relevant to a
#  |      specific set of inputs.
#  |
#  |      Note that `add_loss` is not supported when executing eagerly. Instead,
#  |      variable regularizers may be added through `add_variable`. Activity
#  |      regularization is not supported directly (but such losses may be returned
#  |      from `Layer.call()`).
#  |
#  |      Arguments:
#  |        losses: Loss tensor, or list/tuple of tensors. Rather than tensors, losses
#  |          may also be zero-argument callables which create a loss tensor. Only
#  |          callable losses are supported when executing eagerly.
#  |        inputs: If anything other than None is passed, it signals the losses
#  |          are conditional on some of the layer's inputs,
#  |          and thus they should only be run where these inputs are available.
#  |          This is the case for activity regularization losses, for instance.
#  |          If `None` is passed, the losses are assumed
#  |          to be unconditional, and will apply across all dataflows of the layer
#  |          (e.g. weight regularization losses).
#  |
#  |      Raises:
#  |        RuntimeError: If called in Eager mode with a `Tensor` rather than a
#  |          callable, or if `inputs` is not None.
#  |
#  |  add_weight(self, name, shape, dtype=None, initializer=None, regularizer=None, trainable=None, constraint=None, use_resource=None, synchronization=<VariableSynchronization.AUTO: 0>, aggregation=<VariableAggregation.NONE: 0>, partitioner=None)
#  |      Adds a new variable to the layer, or gets an existing one; returns it.
#  |
#  |      Arguments:
#  |        name: variable name.
#  |        shape: variable shape.
#  |        dtype: The type of the variable. Defaults to `self.dtype` or `float32`.
#  |        initializer: initializer instance (callable).
#  |        regularizer: regularizer instance (callable).
#  |        trainable: whether the variable should be part of the layer's
#  |          "trainable_variables" (e.g. variables, biases)
#  |          or "non_trainable_variables" (e.g. BatchNorm mean, stddev).
#  |          Note, if the current variable scope is marked as non-trainable
#  |          then this parameter is ignored and any added variables are also
#  |          marked as non-trainable. `trainable` defaults to `True` unless
#  |          `synchronization` is set to `ON_READ`.
#  |        constraint: constraint instance (callable).
#  |        use_resource: Whether to use `ResourceVariable`.
#  |        synchronization: Indicates when a distributed a variable will be
#  |          aggregated. Accepted values are constants defined in the class
#  |          `tf.VariableSynchronization`. By default the synchronization is set to
#  |          `AUTO` and the current `DistributionStrategy` chooses
#  |          when to synchronize. If `synchronization` is set to `ON_READ`,
#  |          `trainable` must not be set to `True`.
#  |        aggregation: Indicates how a distributed variable will be aggregated.
#  |          Accepted values are constants defined in the class
#  |          `tf.VariableAggregation`.
#  |        partitioner: (optional) partitioner instance (callable).  If
#  |          provided, when the requested variable is created it will be split
#  |          into multiple partitions according to `partitioner`.  In this case,
#  |          an instance of `PartitionedVariable` is returned.  Available
#  |          partitioners include `tf.fixed_size_partitioner` and
#  |          `tf.variable_axis_size_partitioner`.  For more details, see the
#  |          documentation of `tf.get_variable` and the  "Variable Partitioners
#  |          and Sharding" section of the API guide.
#  |
#  |      Returns:
#  |        The created variable.  Usually either a `Variable` or `ResourceVariable`
#  |        instance.  If `partitioner` is not `None`, a `PartitionedVariable`
#  |        instance is returned.
#  |
#  |      Raises:
#  |        RuntimeError: If called with partioned variable regularization and
#  |          eager execution is enabled.
#  |        ValueError: When trainable has been set to True with synchronization
#  |          set as `ON_READ`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from tensorflow.python.layers.base.Layer:
#  |
#  |  graph
#  |
#  |  scope_name
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from tensorflow.python.keras.engine.base_layer.Layer:
#  |
#  |  add_update(self, updates, inputs=None)
#  |      Add update op(s), potentially dependent on layer inputs.
#  |
#  |      Weight updates (for instance, the updates of the moving mean and variance
#  |      in a BatchNormalization layer) may be dependent on the inputs passed
#  |      when calling a layer. Hence, when reusing the same layer on
#  |      different inputs `a` and `b`, some entries in `layer.updates` may be
#  |      dependent on `a` and some on `b`. This method automatically keeps track
#  |      of dependencies.
#  |
#  |      The `get_updates_for` method allows to retrieve the updates relevant to a
#  |      specific set of inputs.
#  |
#  |      This call is ignored when eager execution is enabled (in that case, variable
#  |      updates are run on the fly and thus do not need to be tracked for later
#  |      execution).
#  |
#  |      Arguments:
#  |        updates: Update op, or list/tuple of update ops.
#  |        inputs: If anything other than None is passed, it signals the updates
#  |          are conditional on some of the layer's inputs,
#  |          and thus they should only be run where these inputs are available.
#  |          This is the case for BatchNormalization updates, for instance.
#  |          If None, the updates will be taken into account unconditionally,
#  |          and you are responsible for making sure that any dependency they might
#  |          have is available at runtime.
#  |          A step counter might fall into this category.
#  |
#  |  add_variable(self, *args, **kwargs)
#  |      Alias for `add_weight`.
#  |
#  |  apply(self, inputs, *args, **kwargs)
#  |      Apply the layer on a input.
#  |
#  |      This simply wraps `self.__call__`.
#  |
#  |      Arguments:
#  |        inputs: Input tensor(s).
#  |        *args: additional positional arguments to be passed to `self.call`.
#  |        **kwargs: additional keyword arguments to be passed to `self.call`.
#  |
#  |      Returns:
#  |        Output tensor(s).
#  |
#  |  compute_mask(self, inputs, mask=None)
#  |      Computes an output mask tensor.
#  |
#  |      Arguments:
#  |          inputs: Tensor or list of tensors.
#  |          mask: Tensor or list of tensors.
#  |
#  |      Returns:
#  |          None or a tensor (or list of tensors,
#  |              one per output tensor of the layer).
#  |
#  |  compute_output_shape(self, input_shape)
#  |      Computes the output shape of the layer.
#  |
#  |      Assumes that the layer will be built
#  |      to match that input shape provided.
#  |
#  |      Arguments:
#  |          input_shape: Shape tuple (tuple of integers)
#  |              or list of shape tuples (one per output tensor of the layer).
#  |              Shape tuples can include None for free dimensions,
#  |              instead of an integer.
#  |
#  |      Returns:
#  |          An input shape tuple.
#  |
#  |  count_params(self)
#  |      Count the total number of scalars composing the weights.
#  |
#  |      Returns:
#  |          An integer count.
#  |
#  |      Raises:
#  |          ValueError: if the layer isn't yet built
#  |            (in which case its weights aren't yet defined).
#  |
#  |  get_config(self)
#  |      Returns the config of the layer.
#  |
#  |      A layer config is a Python dictionary (serializable)
#  |      containing the configuration of a layer.
#  |      The same layer can be reinstantiated later
#  |      (without its trained weights) from this configuration.
#  |
#  |      The config of a layer does not include connectivity
#  |      information, nor the layer class name. These are handled
#  |      by `Network` (one layer of abstraction above).
#  |
#  |      Returns:
#  |          Python dictionary.
#  |
#  |  get_input_at(self, node_index)
#  |      Retrieves the input tensor(s) of a layer at a given node.
#  |
#  |      Arguments:
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      Returns:
#  |          A tensor (or list of tensors if the layer has multiple inputs).
#  |
#  |      Raises:
#  |        RuntimeError: If called in Eager mode.
#  |
#  |  get_input_mask_at(self, node_index)
#  |      Retrieves the input mask tensor(s) of a layer at a given node.
#  |
#  |      Arguments:
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      Returns:
#  |          A mask tensor
#  |          (or list of tensors if the layer has multiple inputs).
#  |
#  |  get_input_shape_at(self, node_index)
#  |      Retrieves the input shape(s) of a layer at a given node.
#  |
#  |      Arguments:
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      Returns:
#  |          A shape tuple
#  |          (or list of shape tuples if the layer has multiple inputs).
#  |
#  |      Raises:
#  |        RuntimeError: If called in Eager mode.
#  |
#  |  get_losses_for(self, inputs)
#  |      Retrieves losses relevant to a specific set of inputs.
#  |
#  |      Arguments:
#  |        inputs: Input tensor or list/tuple of input tensors.
#  |
#  |      Returns:
#  |        List of loss tensors of the layer that depend on `inputs`.
#  |
#  |      Raises:
#  |        RuntimeError: If called in Eager mode.
#  |
#  |  get_output_at(self, node_index)
#  |      Retrieves the output tensor(s) of a layer at a given node.
#  |
#  |      Arguments:
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      Returns:
#  |          A tensor (or list of tensors if the layer has multiple outputs).
#  |
#  |      Raises:
#  |        RuntimeError: If called in Eager mode.
#  |
#  |  get_output_mask_at(self, node_index)
#  |      Retrieves the output mask tensor(s) of a layer at a given node.
#  |
#  |      Arguments:
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      Returns:
#  |          A mask tensor
#  |          (or list of tensors if the layer has multiple outputs).
#  |
#  |  get_output_shape_at(self, node_index)
#  |      Retrieves the output shape(s) of a layer at a given node.
#  |
#  |      Arguments:
#  |          node_index: Integer, index of the node
#  |              from which to retrieve the attribute.
#  |              E.g. `node_index=0` will correspond to the
#  |              first time the layer was called.
#  |
#  |      Returns:
#  |          A shape tuple
#  |          (or list of shape tuples if the layer has multiple outputs).
#  |
#  |      Raises:
#  |        RuntimeError: If called in Eager mode.
#  |
#  |  get_updates_for(self, inputs)
#  |      Retrieves updates relevant to a specific set of inputs.
#  |
#  |      Arguments:
#  |        inputs: Input tensor or list/tuple of input tensors.
#  |
#  |      Returns:
#  |        List of update ops of the layer that depend on `inputs`.
#  |
#  |      Raises:
#  |        RuntimeError: If called in Eager mode.
#  |
#  |  get_weights(self)
#  |      Returns the current weights of the layer.
#  |
#  |      Returns:
#  |          Weights values as a list of numpy arrays.
#  |
#  |  set_weights(self, weights)
#  |      Sets the weights of the layer, from Numpy arrays.
#  |
#  |      Arguments:
#  |          weights: a list of Numpy arrays. The number
#  |              of arrays and their shape must match
#  |              number of the dimensions of the weights
#  |              of the layer (i.e. it should match the
#  |              output of `get_weights`).
#  |
#  |      Raises:
#  |          ValueError: If the provided weights list does not match the
#  |              layer's specifications.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from tensorflow.python.keras.engine.base_layer.Layer:
#  |
#  |  from_config(config) from builtins.type
#  |      Creates a layer from its config.
#  |
#  |      This method is the reverse of `get_config`,
#  |      capable of instantiating the same layer from the config
#  |      dictionary. It does not handle layer connectivity
#  |      (handled by Network), nor weights (handled by `set_weights`).
#  |
#  |      Arguments:
#  |          config: A Python dictionary, typically the
#  |              output of get_config.
#  |
#  |      Returns:
#  |          A layer instance.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from tensorflow.python.keras.engine.base_layer.Layer:
#  |
#  |  activity_regularizer
#  |      Optional regularizer function for the output of this layer.
#  |
#  |  dtype
#  |
#  |  inbound_nodes
#  |      Deprecated, do NOT use! Only for compatibility with external Keras.
#  |
#  |  input
#  |      Retrieves the input tensor(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one input,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      Returns:
#  |          Input tensor or list of input tensors.
#  |
#  |      Raises:
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |      Raises:
#  |        RuntimeError: If called in Eager mode.
#  |        AttributeError: If no inbound nodes are found.
#  |
#  |  input_mask
#  |      Retrieves the input mask tensor(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one inbound node,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      Returns:
#  |          Input mask tensor (potentially None) or list of input
#  |          mask tensors.
#  |
#  |      Raises:
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  input_shape
#  |      Retrieves the input shape(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one input,
#  |      i.e. if it is connected to one incoming layer, or if all inputs
#  |      have the same shape.
#  |
#  |      Returns:
#  |          Input shape, as an integer shape tuple
#  |          (or list of shape tuples, one tuple per input tensor).
#  |
#  |      Raises:
#  |          AttributeError: if the layer has no defined input_shape.
#  |          RuntimeError: if called in Eager mode.
#  |
#  |  losses
#  |      Losses which are associated with this `Layer`.
#  |
#  |      Variable regularization tensors are created when this property is accessed,
#  |      so it is eager safe: accessing `losses` under a `tf.GradientTape` will
#  |      propagate gradients back to the corresponding variables.
#  |
#  |      Returns:
#  |        A list of tensors.
#  |
#  |  name
#  |
#  |  non_trainable_variables
#  |
#  |  non_trainable_weights
#  |
#  |  outbound_nodes
#  |      Deprecated, do NOT use! Only for compatibility with external Keras.
#  |
#  |  output
#  |      Retrieves the output tensor(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one output,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      Returns:
#  |        Output tensor or list of output tensors.
#  |
#  |      Raises:
#  |        AttributeError: if the layer is connected to more than one incoming
#  |          layers.
#  |        RuntimeError: if called in Eager mode.
#  |
#  |  output_mask
#  |      Retrieves the output mask tensor(s) of a layer.
#  |
#  |      Only applicable if the layer has exactly one inbound node,
#  |      i.e. if it is connected to one incoming layer.
#  |
#  |      Returns:
#  |          Output mask tensor (potentially None) or list of output
#  |          mask tensors.
#  |
#  |      Raises:
#  |          AttributeError: if the layer is connected to
#  |          more than one incoming layers.
#  |
#  |  output_shape
#  |      Retrieves the output shape(s) of a layer.
#  |
#  |      Only applicable if the layer has one output,
#  |      or if all outputs have the same shape.
#  |
#  |      Returns:
#  |          Output shape, as an integer shape tuple
#  |          (or list of shape tuples, one tuple per output tensor).
#  |
#  |      Raises:
#  |          AttributeError: if the layer has no defined output shape.
#  |          RuntimeError: if called in Eager mode.
#  |
#  |  trainable_variables
#  |
#  |  trainable_weights
#  |
#  |  updates
#  |
#  |  variables
#  |      Returns the list of all layer variables/weights.
#  |
#  |      Returns:
#  |        A list of variables.
#  |
#  |  weights
#  |      Returns the list of all layer variables/weights.
#  |
#  |      Returns:
#  |        A list of variables.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from tensorflow.python.training.checkpointable.base.CheckpointableBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
rnn.BidirectionalGridLSTMCell(128, num_frequency_blocks=[1,1])
